# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy, scipy as sklearn, librosa, urllib
import librosa.display
from IPython.display import Audio
import json 
import seaborn as sns
from sklearn.cluster import KMeans
import csv
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score
import keras
from sklearn.decomposition import PCA

from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tqdm import tqdm
from sklearn.preprocessing import MinMaxScaler

from itertools import cycle
from sklearn.manifold import TSNE
from sklearn.metrics import roc_curve, auc, silhouette_score,roc_auc_score, precision_recall_fscore_support
from tqdm import tqdm

# %%
def get_data_df():
    data_df = pd.read_csv("RAVDESS/data.csv")
    data_df.drop(data_df[data_df['label'] == "calm"].index, inplace = True)
    data_df = data_df.reset_index()
    return data_df

# %%
#add white noise to the original signal
def noise_addition(data,noise_percentage_factor=0.035):
    noise = np.random.normal(0, data.std(), data.size)
    augmented_data = data + noise * noise_percentage_factor
    return augmented_data

#lower the pitch of the original signal
def pitch_scaling(data, sr, num_semitones=-2):
    return librosa.effects.pitch_shift(y = data,sr = sr,n_steps = num_semitones)

#increase the pitch of the original signal
def pitch_scaling2(data, sr, num_semitones=2):
    return librosa.effects.pitch_shift(y = data,sr = sr,n_steps = num_semitones)

# %%
#mfccs and deltas extraction
import math
def extract_mfccs_delta(path):
    y,sr=librosa.load(path)  
    duration=librosa.get_duration(y=y,sr=sr)
    #reduce the duration of files longer than 3 seconds
    if(duration > 3.0):
        y,sr=librosa.load(path, offset=(duration/2)-1.5 , duration = 3)
    else:
        y,sr=librosa.load(path)

    mfcc= librosa.feature.mfcc( y=y,  sr=sr, n_mfcc=13 )
    
    return mfcc

def extract_mfccs_delta_with_noise(path):
    y, sr = librosa.load(path)
    duration=librosa.get_duration(y=y,sr=sr)
    #reduce the duration of files longer than 3 seconds
    if(duration > 3.0):
        y,sr=librosa.load(path, offset=(duration/2)-1.5 , duration = 3)
        y=noise_addition(y)
    else:
        y,sr=librosa.load(path)
        y=noise_addition(y)
    mfcc= librosa.feature.mfcc( y=y,  sr=sr, n_mfcc=13 )
    
    return mfcc


def extract_mfccs_delta_with_pitch_scaling(path):
    y, sr = librosa.load(path)
    duration=librosa.get_duration(y=y,sr=sr)
    #reduce the duration of files longer than 3 seconds
    if(duration > 3.0):
        y,sr=librosa.load(path, offset=(duration/2)-1.5 , duration = 3)
        y=pitch_scaling(y,sr)
    else:
        y,sr=librosa.load(path)
        y=pitch_scaling(y,sr)
    mfcc= librosa.feature.mfcc( y=y,  sr=sr, n_mfcc=13 )
    
    return mfcc

def extract_mfccs_delta_with_pitch_scaling2(path):
    y, sr = librosa.load(path)
    duration=librosa.get_duration(y=y,sr=sr)
    #reduce the duration of files longer than 3 seconds
    if(duration > 3.0):
        y,sr=librosa.load(path, offset=(duration/2)-1.5 , duration = 3)
        y=pitch_scaling2(y,sr)
    else:
        y,sr=librosa.load(path)
        y=pitch_scaling2(y,sr)
    mfcc= librosa.feature.mfcc( y=y,  sr=sr, n_mfcc=13 )
    
    return mfcc

# %%
#log-mel spectrogram extraction
def extract_logmel(path):
    y, sr = librosa.load(path)
    duration=librosa.get_duration(y=y,sr=sr)
    #reduce the duration of files longer than 3 seconds
    if(duration > 3.0):
        y,sr=librosa.load(path, offset=(duration/2)-1.5 , duration = 3)
    else:
        y, sr = librosa.load(path)
    ps = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=60)
    ps_db= librosa.power_to_db(ps)
    return ps_db

def extract_logmel_with_noise(path):
  y, sr = librosa.load(path)
  duration=librosa.get_duration(y=y,sr=sr)
  #reduce the duration of files longer than 3 seconds
  if(duration > 3.0):
      y,sr=librosa.load(path, offset=(duration/2)-1.5 , duration = 3)
      y=noise_addition(y)
  else:
      y, sr = librosa.load(path)
      y=noise_addition(y)
  ps = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=60)
  ps_db= librosa.power_to_db(ps)
  return ps_db

def extract_logmel_with_pitch_scaling(path):
  y, sr = librosa.load(path)
  duration=librosa.get_duration(y=y,sr=sr)
  #reduce the duration of files longer than 3 seconds
  if(duration > 3.0):
      y,sr=librosa.load(path, offset=(duration/2)-1.5 , duration = 3)
      y=pitch_scaling(y,sr)
  else:
      y, sr = librosa.load(path)
      y=pitch_scaling(y,sr)
  ps = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=60)
  ps_db= librosa.power_to_db(ps)
  return ps_db
  

def extract_logmel_with_pitch_scaling2(path):
  y, sr = librosa.load(path)
  duration=librosa.get_duration(y=y,sr=sr)
  #reduce the duration of files longer than 3 seconds
  if(duration > 3.0):
      y,sr=librosa.load(path, offset=(duration/2)-1.5 , duration = 3)
      y=pitch_scaling2(y,sr)
  else:
      y, sr = librosa.load(path)
      y=pitch_scaling2(y,sr)
  ps = librosa.feature.melspectrogram(y=y, sr=sr, n_mels=60)
  ps_db= librosa.power_to_db(ps)
  return ps_db

# %%
not_aug_df = get_data_df()

for i in range(0,13):
    not_aug_df["mfcc_"+str(i)]= None
    
for i in range(0,13):
    not_aug_df["delta_"+str(i)]= None
    
for i in range(0,60):
    not_aug_df["logmel_"+str(i)]= None

for  (index ,path) in tqdm(zip(not_aug_df.index,not_aug_df.file_name)):
        mfccs=extract_mfccs_delta('RAVDESS/'+path)
        delta=librosa.feature.delta(mfccs)
        logmel=extract_logmel('RAVDESS/'+path)
        #add zero padding
        if mfccs.shape[1]<130:
          mfccs=librosa.util.pad_center(mfccs, size=130, axis=1)
          delta=librosa.util.pad_center(delta, size=130, axis=1)
          logmel=librosa.util.pad_center(logmel, size=130, axis=1)
        for i in range(0,13):
            not_aug_df.at[index, "mfcc_"+str(i)] = mfccs[i]
        for j in range(0,13):
            not_aug_df.at[index, "delta_"+str(j)] = delta[j]
        for z in range(0,60):
            not_aug_df.at[index, "logmel_"+str(z)] = logmel[z]
# Out:
# 0it [00:00, ?it/s]
# 1248it [00:16, 77.18it/s]

# %%
pitch_df = get_data_df()
pitch_df= pd.concat([pitch_df]*2, ignore_index=True)   
for i in range(0,13):
    pitch_df["mfcc_"+str(i)]= None

for i in range(0,13):
    pitch_df["delta_"+str(i)]= None

for i in range(0,60):
    pitch_df["logmel_"+str(i)]= None

for  (index ,path) in tqdm(zip(pitch_df[0:len(pitch_df)//2].index,pitch_df[0:len(pitch_df)//2].file_name)):
        mfccs=extract_mfccs_delta_with_pitch_scaling('RAVDESS/'+path)
        logmel=extract_logmel_with_pitch_scaling('RAVDESS/'+path)
        delta=librosa.feature.delta(mfccs)
        #add zero padding
        if mfccs.shape[1]<130:
          mfccs=librosa.util.pad_center(mfccs, size=130, axis=1)
          delta=librosa.util.pad_center(delta, size=130, axis=1)
          logmel=librosa.util.pad_center(logmel, size=130, axis=1)
        for i in range(0,13):
            pitch_df.at[index, "mfcc_"+str(i)] = mfccs[i]
        for j in range(0,13):
            pitch_df.at[index, "delta_"+str(j)] = delta[j]
        for z in range(0,60):
            pitch_df.at[index, "logmel_"+str(z)] = logmel[z]
    
for  (index ,path) in tqdm(zip(pitch_df[len(pitch_df)//2:].index,pitch_df[len(pitch_df)//2:].file_name)):
        mfccs=extract_mfccs_delta_with_pitch_scaling2('RAVDESS/'+path)
        logmel=extract_logmel_with_pitch_scaling2('RAVDESS/'+path)
        delta=librosa.feature.delta(mfccs)
        #add zero padding
        if mfccs.shape[1]<130:
          mfccs=librosa.util.pad_center(mfccs, size=130, axis=1)
          delta=librosa.util.pad_center(delta, size=130, axis=1)
          logmel=librosa.util.pad_center(logmel, size=130, axis=1)
        for i in range(0,13):
            pitch_df.at[index, "mfcc_"+str(i)] = mfccs[i]
        for j in range(0,13):
            pitch_df.at[index, "delta_"+str(j)] = delta[j]
        for z in range(0,60):
            pitch_df.at[index, "logmel_"+str(z)] = logmel[z]


#join the two datasets
frames = [ not_aug_df, pitch_df]
semi_aug_df=pd.concat(frames ,ignore_index=True)
# Out:
# 1248it [00:53, 23.23it/s]
# 1248it [01:02, 19.98it/s]

# %%
noise_df = get_data_df()
for i in range(0,13):
    noise_df["mfcc_"+str(i)]= None
for i in range(0,13):
    noise_df["delta_"+str(i)]= None
for i in range(0,60):
    noise_df["logmel_"+str(i)]= None


for  (index ,path) in tqdm(zip(noise_df.index,noise_df.file_name)):
        mfccs=extract_mfccs_delta_with_noise('RAVDESS/'+path)
        logmel=extract_logmel_with_noise('RAVDESS/'+path)
        delta=librosa.feature.delta(mfccs)
        #add zero padding
        if mfccs.shape[1]<130:
          mfccs=librosa.util.pad_center(mfccs, size=130, axis=1)
          delta=librosa.util.pad_center(delta, size=130, axis=1)
          logmel=librosa.util.pad_center(logmel, size=130, axis=1)
        for i in range(0,13):
            noise_df.at[index, "mfcc_"+str(i)] = mfccs[i]
        for j in range(0,13):
            noise_df.at[index, "delta_"+str(j)] = delta[j]
        for z in range(0,60):
            noise_df.at[index, "logmel_"+str(z)] = logmel[z]

frames = [ semi_aug_df, noise_df]
aug_df=pd.concat(frames,ignore_index=True)
# Out:
# 1248it [00:24, 50.71it/s]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(not_aug_df['label'])
not_aug_df['label_id']=le.transform(not_aug_df['label'])
semi_aug_df['label_id']=le.transform(semi_aug_df['label'])
aug_df['label_id']=le.transform(aug_df['label'])

# %%
not_aug_df.to_pickle('RAVDESS/not_aug_df.pkl')
semi_aug_df.to_pickle('RAVDESS/semi_aug_df.pkl')
aug_df.to_pickle('RAVDESS/aug_df.pkl')

# %%
not_aug_df=pd.read_pickle('RAVDESS/not_aug_df.pkl')
semi_aug_df=pd.read_pickle('RAVDESS/semi_aug_df.pkl')
aug_df=pd.read_pickle('RAVDESS/aug_df.pkl')

# %%
scaler = StandardScaler()

#extraction of the log mel specrogram from the datasets - not aug
X_logmel_k = np.array(not_aug_df.loc[:, ['logmel' in i for i in not_aug_df.columns]])
X_logmel_k=np.array(X_logmel_k.tolist())
X_logmel_k=scaler.fit_transform(X_logmel_k.reshape(-1, X_logmel_k.shape[-1])).reshape(X_logmel_k.shape)
Y_logmel_k=not_aug_df['label']

#reshape the data from 3D to 2D - not aug
X_logmel_k=X_logmel_k.reshape(X_logmel_k.shape[0],X_logmel_k.shape[1]*X_logmel_k.shape[2])

# %%
#extraction of labels_id from datasets
Y_not_aug=not_aug_df['label_id']
Y_semi_aug=semi_aug_df['label_id']
Y_aug=aug_df['label_id']

#take the log mel spectrogram from the datasets
X_logmel = np.array(not_aug_df.loc[:, ['logmel' in i for i in not_aug_df.columns]])
X_logmel=np.array(X_logmel.tolist())
X_logmel_semi_aug = np.array(semi_aug_df.loc[:, ['logmel' in i for i in semi_aug_df.columns]])
X_logmel_semi_aug=np.array(X_logmel_semi_aug.tolist())
X_logmel_aug = np.array(aug_df.loc[:, ['logmel' in i for i in aug_df.columns]])
X_logmel_aug=np.array(X_logmel_aug.tolist())


X_logmel = np.reshape(X_logmel, (X_logmel.shape[0],X_logmel.shape[1],X_logmel.shape[2],1))
X_logmel_semi_aug= np.reshape(X_logmel_semi_aug, (X_logmel_semi_aug.shape[0],X_logmel_semi_aug.shape[1],X_logmel_semi_aug.shape[2],1))
X_logmel_aug= np.reshape(X_logmel_aug, (X_logmel_aug.shape[0],X_logmel_aug.shape[1],X_logmel_aug.shape[2],1))

# %%
def get_train_val_test(X,Y):
    X = scaler.fit_transform(X.reshape(-1, X.shape[-1])).reshape(X.shape)
    Y = keras.utils.to_categorical(Y.to_numpy())
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=22)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=22)
    return X_train, X_val, X_test, y_train,  y_val, y_test

# %%
def get_cnn(input_shape):
    model = keras.Sequential()

    model.add(keras.layers.Input(shape=input_shape))

    model.add(keras.layers.Conv2D(256, 3, activation='relu' ))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))

    model.add(keras.layers.Conv2D(128, 3, activation='relu'))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))


    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))

    model.add(keras.layers.GlobalAveragePooling2D())
    model.add(keras.layers.Dense(1024, activation='relu'))
    
    model.add(keras.layers.Dense(256, activation='relu'))
    model.add(keras.layers.Dense(64, activation='relu'))

    model.add(keras.layers.Dense(7, activation='softmax'))

    optimzer = keras.optimizers.Adam()
    model.compile(loss='categorical_crossentropy', optimizer=optimzer, metrics=['accuracy'])

    return model

# %% [markdown]
# ### TRAINING mel

# %%
from datetime import datetime  
name = datetime.now().strftime("models/augmented_vs_clean/SER_RAVDESS_clean_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=10,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

X_train, X_val, X_test, y_train,  y_val, y_test = get_train_val_test(X_logmel,Y_not_aug)

model = get_cnn((X_train.shape[1:]))
# model.summary()
history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=256,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.1251 - loss: 1.9436
# Epoch 1: val_loss improved from inf to 1.88091, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 28s 5s/step - accuracy: 0.1264 - loss: 1.9423 - val_accuracy: 0.2800 - val_loss: 1.8809
# Epoch 2/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2319 - loss: 1.8309
# Epoch 2: val_loss improved from 1.88091 to 1.77193, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 19s 4s/step - accuracy: 0.2318 - loss: 1.8272 - val_accuracy: 0.3022 - val_loss: 1.7719
# Epoch 3/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2512 - loss: 1.7790
# Epoch 3: val_loss improved from 1.77193 to 1.73725, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step - accuracy: 0.2506 - loss: 1.7759 - val_accuracy: 0.2978 - val_loss: 1.7372
# Epoch 4/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2626 - loss: 1.7527
# Epoch 4: val_loss improved from 1.73725 to 1.72990, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.2622 - loss: 1.7519 - val_accuracy: 0.3067 - val_loss: 1.7299
# Epoch 5/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2740 - loss: 1.7335
# Epoch 5: val_loss improved from 1.72990 to 1.71956, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.2735 - loss: 1.7321 - val_accuracy: 0.2756 - val_loss: 1.7196
# Epoch 6/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2651 - loss: 1.7077
# Epoch 6: val_loss did not improve from 1.71956
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.2660 - loss: 1.7082 - val_accuracy: 0.2844 - val_loss: 1.7326
# Epoch 7/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2668 - loss: 1.7221
# Epoch 7: val_loss did not improve from 1.71956
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.2662 - loss: 1.7201 - val_accuracy: 0.2578 - val_loss: 1.7270
# Epoch 8/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2556 - loss: 1.7026
# Epoch 8: val_loss improved from 1.71956 to 1.70075, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step - accuracy: 0.2559 - loss: 1.7020 - val_accuracy: 0.2933 - val_loss: 1.7007
# Epoch 9/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2834 - loss: 1.6993
# Epoch 9: val_loss did not improve from 1.70075
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step - accuracy: 0.2828 - loss: 1.6986 - val_accuracy: 0.2889 - val_loss: 1.7277
# Epoch 10/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2629 - loss: 1.7122
# Epoch 10: val_loss improved from 1.70075 to 1.70021, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step - accuracy: 0.2654 - loss: 1.7106 - val_accuracy: 0.3111 - val_loss: 1.7002
# Epoch 11/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2468 - loss: 1.7207
# Epoch 11: val_loss improved from 1.70021 to 1.68619, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.2502 - loss: 1.7142 - val_accuracy: 0.3289 - val_loss: 1.6862
# Epoch 12/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2691 - loss: 1.7023
# Epoch 12: val_loss improved from 1.68619 to 1.67517, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step - accuracy: 0.2734 - loss: 1.6970 - val_accuracy: 0.3022 - val_loss: 1.6752
# Epoch 13/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2875 - loss: 1.6732
# Epoch 13: val_loss did not improve from 1.67517
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.2873 - loss: 1.6741 - val_accuracy: 0.2978 - val_loss: 1.7145
# Epoch 14/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2541 - loss: 1.6761
# Epoch 14: val_loss improved from 1.67517 to 1.67326, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 19s 5s/step - accuracy: 0.2547 - loss: 1.6777 - val_accuracy: 0.2844 - val_loss: 1.6733
# Epoch 15/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.2872 - loss: 1.6904
# Epoch 15: val_loss improved from 1.67326 to 1.66190, saving model to models/augmented_vs_clean/SER_RAVDESS_clean_07_10_2024_16_32_30.keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 22s 5s/step
keras
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.3840 - loss: 1.5217 - val_accuracy: 0.3733 - val_loss: 1.5536
# Epoch 32/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3677 - loss: 1.5464
# Epoch 32: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step - accuracy: 0.3701 - loss: 1.5423 - val_accuracy: 0.3822 - val_loss: 1.5634
# Epoch 33/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3868 - loss: 1.5296
# Epoch 33: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step - accuracy: 0.3874 - loss: 1.5281 - val_accuracy: 0.3511 - val_loss: 1.5716
# Epoch 34/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5s/step - accuracy: 0.4018 - loss: 1.4961
# Epoch 34: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 20s 5s/step - accuracy: 0.3985 - loss: 1.5011 - val_accuracy: 0.3911 - val_loss: 1.5536
# Epoch 35/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4046 - loss: 1.4810
# Epoch 35: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 18s 4s/step - accuracy: 0.4037 - loss: 1.4849 - val_accuracy: 0.3333 - val_loss: 1.6522
# Epoch 36/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3763 - loss: 1.5361
# Epoch 36: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 14s 3s/step - accuracy: 0.3763 - loss: 1.5352 - val_accuracy: 0.3644 - val_loss: 1.5549
# Epoch 37/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3983 - loss: 1.5190
# Epoch 37: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.3962 - loss: 1.5225 - val_accuracy: 0.3422 - val_loss: 1.6427
# Epoch 38/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3743 - loss: 1.5574
# Epoch 38: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.3743 - loss: 1.5560 - val_accuracy: 0.2844 - val_loss: 1.7237
# Epoch 39/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3266 - loss: 1.6308
# Epoch 39: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.3263 - loss: 1.6227 - val_accuracy: 0.3200 - val_loss: 1.6493
# Epoch 40/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3553 - loss: 1.5804
# Epoch 40: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.3590 - loss: 1.5727 - val_accuracy: 0.3600 - val_loss: 1.6066
# Epoch 41/1000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3934 - loss: 1.5127
# Epoch 41: val_loss did not improve from 1.55358
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 11s 3s/step - accuracy: 0.3923 - loss: 1.5150 - val_accuracy: 0.3778 - val_loss: 1.5632
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 31.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.3228 - loss: 1.6525
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3228 - loss: 1.6525
# Loss : 1.6669886112213135, Accuracy : 0.3199999928474426

# %%
print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.3228 - loss: 1.6525
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - accuracy: 0.3228 - loss: 1.6525
# Loss : 1.6669886112213135, Accuracy : 0.3199999928474426

# %%
from datetime import datetime  
name = datetime.now().strftime("models/augmented_vs_clean/SER_RAVDESS_semi_aug_scaled_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=5,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

X_train, X_val, X_test, y_train,  y_val, y_test = get_train_val_test(X_logmel_semi_aug,Y_semi_aug)

model = get_cnn((X_train.shape[1:]))
# model.summary()

history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=256,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2163 - loss: 1.9007
# Epoch 1: val_loss improved from inf to 1.68281, saving model to models/augmented_vs_clean/SER_RAVDESS_semi_aug_scaled_07_10_2024_16_53_06.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 41s 4s/step - accuracy: 0.2175 - loss: 1.8966 - val_accuracy: 0.2938 - val_loss: 1.6828
# Epoch 2/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2411 - loss: 1.7922
# Epoch 2: val_loss did not improve from 1.68281
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 39s 4s/step - accuracy: 0.2410 - loss: 1.7913 - val_accuracy: 0.2493 - val_loss: 1.7419
# Epoch 3/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2684 - loss: 1.7389
# Epoch 3: val_loss improved from 1.68281 to 1.67930, saving model to models/augmented_vs_clean/SER_RAVDESS_semi_aug_scaled_07_10_2024_16_53_06.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.2691 - loss: 1.7383 - val_accuracy: 0.2953 - val_loss: 1.6793
# Epoch 4/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.
saving model to models/augmented_vs_clean/SER_RAVDESS_semi_aug_scaled_07_10_2024_16_53_06.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 35s 3s/step - accuracy: 0.6194 - loss: 0.9649 - val_accuracy: 0.6588 - val_loss: 0.9453
# Epoch 74/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6355 - loss: 0.9407
# Epoch 74: val_loss improved from 0.94532 to 0.94092, saving model to models/augmented_vs_clean/SER_RAVDESS_semi_aug_scaled_07_10_2024_16_53_06.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6350 - loss: 0.9419 - val_accuracy: 0.6454 - val_loss: 0.9409
# Epoch 75/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6483 - loss: 0.8970
# Epoch 75: val_loss did not improve from 0.94092
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.6474 - loss: 0.8999 - val_accuracy: 0.6380 - val_loss: 0.9593
# Epoch 76/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6470 - loss: 0.9229
# Epoch 76: val_loss improved from 0.94092 to 0.92616, saving model to models/augmented_vs_clean/SER_RAVDESS_semi_aug_scaled_07_10_2024_16_53_06.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.6470 - loss: 0.9231 - val_accuracy: 0.6721 - val_loss: 0.9262
# Epoch 77/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6638 - loss: 0.8885
# Epoch 77: val_loss improved from 0.92616 to 0.91729, saving model to models/augmented_vs_clean/SER_RAVDESS_semi_aug_scaled_07_10_2024_16_53_06.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.6640 - loss: 0.8887 - val_accuracy: 0.6306 - val_loss: 0.9173
# Epoch 78/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6385 - loss: 0.9292
# Epoch 78: val_loss improved from 0.91729 to 0.90235, saving model to models/augmented_vs_clean/SER_RAVDESS_semi_aug_scaled_07_10_2024_16_53_06.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.6384 - loss: 0.9290 - val_accuracy: 0.6677 - val_loss: 0.9024
# Epoch 79/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6570 - loss: 0.9068
# Epoch 79: val_loss did not improve from 0.90235
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.6552 - loss: 0.9104 - val_accuracy: 0.6677 - val_loss: 0.9457
# Epoch 80/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6531 - loss: 0.9298
# Epoch 80: val_loss did not improve from 0.90235
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.6529 - loss: 0.9300 - val_accuracy: 0.6573 - val_loss: 0.9213
# Epoch 81/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6721 - loss: 0.8815
# Epoch 81: val_loss did not improve from 0.90235
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.6709 - loss: 0.8825 - val_accuracy: 0.6320 - val_loss: 0.9772
# Epoch 82/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6407 - loss: 0.9255
# Epoch 82: val_loss did not improve from 0.90235
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 32s 3s/step - accuracy: 0.6405 - loss: 0.9270 - val_accuracy: 0.6024 - val_loss: 0.9912
# Epoch 83/1000
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6500 - loss: 0.8860
# Epoch 83: val_loss did not improve from 0.90235
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 33s 3s/step - accuracy: 0.6492 - loss: 0.8865 - val_accuracy: 0.6617 - val_loss: 0.9171
# Epoch 83: early stopping
# Restoring model weights from the end of the best epoch: 78.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.6737 - loss: 0.9027
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.6737 - loss: 0.9027
# Loss : 0.9634571671485901, Accuracy : 0.6399999856948853

# %%
from datetime import datetime  
name = datetime.now().strftime("models/augmented_vs_clean/SER_RAVDESS_aug_scaled_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=5,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

X_train, X_val, X_test, y_train,  y_val, y_test = get_train_val_test(X_logmel_aug,Y_aug)

model = get_cnn((X_train.shape[1:]))
# model.summary()

history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=256,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2047 - loss: 1.8803
# Epoch 1: val_loss improved from inf to 1.78322, saving model to models/augmented_vs_clean/SER_RAVDESS_aug_scaled_07_10_2024_18_06_56.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.2062 - loss: 1.8775 - val_accuracy: 0.2581 - val_loss: 1.7832
# Epoch 2/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2587 - loss: 1.7653
# Epoch 2: val_loss improved from 1.78322 to 1.74484, saving model to models/augmented_vs_clean/SER_RAVDESS_aug_scaled_07_10_2024_18_06_56.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 38s 3s/step - accuracy: 0.2590 - loss: 1.7650 - val_accuracy: 0.2625 - val_loss: 1.7448
# Epoch 3/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2849 - loss: 1.7334
# Epoch 3: val_loss did not improve from 1.74484
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 41s 3s/step - accuracy: 0.2847 - loss: 1.7324 - val_accuracy: 0.2369 - val_loss: 1.7947
# Epoch 4/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2756 - loss: 1.7634
# Epoch 4: val_loss improved from 1.74484 to 1.74353, saving model to models/augmented_vs_clean/SER_RAVDESS_aug_scaled_07_10_2024_18_06_56.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 40s 3s/step - accuracy: 0
saving model to models/augmented_vs_clean/SER_RAVDESS_aug_scaled_07_10_2024_18_06_56.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.3630 - loss: 1.5745 - val_accuracy: 0.3815 - val_loss: 1.5488
# Epoch 23/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3951 - loss: 1.5409
# Epoch 23: val_loss did not improve from 1.54881
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.3947 - loss: 1.5403 - val_accuracy: 0.3704 - val_loss: 1.6007
# Epoch 24/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3703 - loss: 1.5872
# Epoch 24: val_loss did not improve from 1.54881
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.3706 - loss: 1.5859 - val_accuracy: 0.3571 - val_loss: 1.5983
# Epoch 25/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3919 - loss: 1.5276
# Epoch 25: val_loss did not improve from 1.54881
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.3915 - loss: 1.5270 - val_accuracy: 0.3815 - val_loss: 1.5537
# Epoch 26/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3833 - loss: 1.5197
# Epoch 26: val_loss improved from 1.54881 to 1.52149, saving model to models/augmented_vs_clean/SER_RAVDESS_aug_scaled_07_10_2024_18_06_56.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 43s 3s/step - accuracy: 0.3838 - loss: 1.5195 - val_accuracy: 0.4071 - val_loss: 1.5215
# Epoch 27/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4153 - loss: 1.4766
# Epoch 27: val_loss did not improve from 1.52149
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 46s 3s/step - accuracy: 0.4147 - loss: 1.4771 - val_accuracy: 0.3582 - val_loss: 1.5400
# Epoch 28/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3988 - loss: 1.4934
# Epoch 28: val_loss did not improve from 1.52149
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.3996 - loss: 1.4928 - val_accuracy: 0.3582 - val_loss: 1.6216
# Epoch 29/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3725 - loss: 1.5958
# Epoch 29: val_loss improved from 1.52149 to 1.51759, saving model to models/augmented_vs_clean/SER_RAVDESS_aug_scaled_07_10_2024_18_06_56.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.3728 - loss: 1.5937 - val_accuracy: 0.3993 - val_loss: 1.5176
# Epoch 30/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4085 - loss: 1.4982
# Epoch 30: val_loss improved from 1.51759 to 1.50696, saving model to models/augmented_vs_clean/SER_RAVDESS_aug_scaled_07_10_2024_18_06_56.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.4087 - loss: 1.4978 - val_accuracy: 0.4016 - val_loss: 1.5070
# Epoch 31/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4164 - loss: 1.4492
# Epoch 31: val_loss improved from 1.50696 to 1.46931, saving model to models/augmented_vs_clean/SER_RAVDESS_aug_scaled_07_10_2024_18_06_56.keras
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.4168 - loss: 1.4492 - val_accuracy: 0.4027 - val_loss: 1.4693
# Epoch 32/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4206 - loss: 1.4427
# Epoch 32: val_loss did not improve from 1.46931
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.4207 - loss: 1.4429 - val_accuracy: 0.2814 - val_loss: 1.7784
# Epoch 33/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3788 - loss: 1.5596
# Epoch 33: val_loss did not improve from 1.46931
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.3797 - loss: 1.5567 - val_accuracy: 0.3237 - val_loss: 1.6851
# Epoch 34/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3978 - loss: 1.5650
# Epoch 34: val_loss did not improve from 1.46931
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.3983 - loss: 1.5624 - val_accuracy: 0.3749 - val_loss: 1.5094
# Epoch 35/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4304 - loss: 1.4488
# Epoch 35: val_loss did not improve from 1.46931
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 47s 3s/step - accuracy: 0.4308 - loss: 1.4482 - val_accuracy: 0.3693 - val_loss: 1.5204
# Epoch 36/1000
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4304 - loss: 1.4379
# Epoch 36: val_loss did not improve from 1.46931
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 45s 3s/step - accuracy: 0.4310 - loss: 1.4365 - val_accuracy: 0.4027 - val_loss: 1.4776
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 31.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 101ms/step - accuracy: 0.4305 - loss: 1.4863
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 100ms/step - accuracy: 0.4305 - loss: 1.4863
# Loss : 1.513410210609436, Accuracy : 0.4180000126361847

# %%
import keras
from keras import layers, models

def get_model(input_shape):
    inputs = layers.Input(shape=input_shape)
    encoder = layers.LSTM(128)(inputs)
    drop = layers.Dropout(0.3)(encoder)
    hidden = layers.Dense(32, activation='relu')(drop)
    outputs = layers.Dense(7, activation='softmax')(hidden)
    
    model = models.Model(inputs, outputs)
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=["accuracy"])

    return model

# %%
X_train,X_val,X_test,y_train,y_val,y_test = get_train_val_test(X_logmel.squeeze(3),Y_not_aug)
LSTM_model = get_model(X_train.shape[1:])
# LSTM_model.summary()

# %%
X_test.shape
# Out:
# (125, 60, 130)

# %%
from datetime import datetime  
name = datetime.now().strftime("models/RAVDESS_lstm_clean_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=20,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]


LSTM_history = LSTM_model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       verbose=1,
                       callbacks=callbacks)


print(f"Loss : {LSTM_model.evaluate(X_test,y_test)[0]}, Accuracy : {LSTM_model.evaluate(X_test,y_test)[1]}")

# %%
X_train,X_val,X_test,y_train,y_val,y_test = get_train_val_test(X_logmel_semi_aug.squeeze(3),Y_semi_aug)
LSTM_model = get_model(X_train.shape[1:])
# LSTM_model.summary()


from datetime import datetime  
name = datetime.now().strftime("models/RAVDESS_lstm_semi_aug_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=20,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]


LSTM_history = LSTM_model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       verbose=1,
                       callbacks=callbacks)


print(f"Loss : {LSTM_model.evaluate(X_test,y_test)[0]}, Accuracy : {LSTM_model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 82/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2589 - loss: 1.7925
# Epoch 1: val_loss improved from inf to 1.50034, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.2617 - loss: 1.7879 - val_accuracy: 0.4199 - val_loss: 1.5003
# Epoch 2/1000
# 82/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4409 - loss: 1.4692
# Epoch 2: val_loss improved from 1.50034 to 1.37527, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.4403 - loss: 1.4687 - val_accuracy: 0.4659 - val_loss: 1.3753
# Epoch 3/1000
# 82/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4593 - loss: 1.3786
# Epoch 3: val_loss improved from 1.37527 to 1.28430, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.4604 - loss: 1.3764 - val_accuracy: 0.4822 - val_loss: 1.2843
# Epoch 4/1000
# 82/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4986 - loss: 1.2423
# Epoch 4: val_loss improved from 1.28430 to 1.21931, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.4990 - loss: 1.2423 - val_accuracy: 0.5045 - val_loss: 1.2193
# Epoch 5/1000
# 84/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5362 - loss: 1.1985
# Epoch 5: val_loss improved from 1.21931 to 1.18141, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.5365 - loss: 1.1975 - val_accuracy: 0.5148 - val_loss: 1.1814
# Epoch 6/1000
# 84/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.6133 - loss: 1.0303
# Epoch 6: val_loss improved from 1.18141 to 1.07630, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6133 - loss: 1.0298 - val_accuracy: 0.5712 - val_loss: 1.0763
# Epoch 7/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6348 - loss: 0.9755
# Epoch 7: val_loss improved from 1.07630 to 1.07055, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.6349 - loss: 0.9754 - val_accuracy: 0.5950 - val_loss: 1.0706
# Epoch 8/1000
# 84/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.6713 - loss: 0.8700
# Epoch 8: val_loss did not improve from 1.07055
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.6715 - loss: 0.8699 - val_accuracy: 0.5786 - val_loss: 1.1143
# Epoch 9/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7022 - loss: 0.8029
# Epoch 9: val_loss improved from 1.07055 to 0.98532, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7023 - loss: 0.8025 - val_accuracy: 0.6261 - val_loss: 0.9853
# Epoch 10/1000
# 83/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.7349 - loss: 0.7240
# Epoch 10: val_loss improved from 0.98532 to 0.91312, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7347 - loss: 0.7242 - val_accuracy: 0.6543 - val_loss: 0.9131
# Epoch 11/1000
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7593 - loss: 0.6380
# Epoch 11: val_loss improved from 0.91312 to 0.84361, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.7595 - loss: 0.6377 - val_accuracy: 0.7077 - val_loss: 0.8436
# Epoch 12/1000
# 84/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.7878 - loss: 0.5987
# Epoch 12: val_loss improved from 0.84361 to 0.82641, saving model to models/RAVDESS_lstm_semi_aug_07_10_2024_18_33_53.keras
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.
1000
# 83/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9804 - loss: 0.0615
# Epoch 49: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9804 - loss: 0.0613 - val_accuracy: 0.8917 - val_loss: 0.5116
# Epoch 50/1000
# 84/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9766 - loss: 0.0821
# Epoch 50: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9763 - loss: 0.0830 - val_accuracy: 0.8591 - val_loss: 0.5709
# Epoch 51/1000
# 83/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9474 - loss: 0.1681
# Epoch 51: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9472 - loss: 0.1685 - val_accuracy: 0.8591 - val_loss: 0.6167
# Epoch 52/1000
# 84/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9635 - loss: 0.1257
# Epoch 52: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9635 - loss: 0.1258 - val_accuracy: 0.8501 - val_loss: 0.6196
# Epoch 53/1000
# 83/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9738 - loss: 0.0788
# Epoch 53: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9737 - loss: 0.0789 - val_accuracy: 0.8680 - val_loss: 0.6157
# Epoch 54/1000
# 83/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9833 - loss: 0.0584
# Epoch 54: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9832 - loss: 0.0585 - val_accuracy: 0.8828 - val_loss: 0.5430
# Epoch 55/1000
# 82/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9859 - loss: 0.0495
# Epoch 55: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9858 - loss: 0.0497 - val_accuracy: 0.8947 - val_loss: 0.5207
# Epoch 56/1000
# 83/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9906 - loss: 0.0348
# Epoch 56: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9906 - loss: 0.0349 - val_accuracy: 0.8961 - val_loss: 0.5366
# Epoch 57/1000
# 82/85 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9898 - loss: 0.0392
# Epoch 57: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9898 - loss: 0.0390 - val_accuracy: 0.9006 - val_loss: 0.5354
# Epoch 58/1000
# 82/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9816 - loss: 0.0629
# Epoch 58: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9816 - loss: 0.0628 - val_accuracy: 0.8680 - val_loss: 0.5766
# Epoch 59/1000
# 84/85 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9713 - loss: 0.0912
# Epoch 59: val_loss did not improve from 0.44787
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9713 - loss: 0.0915 - val_accuracy: 0.8620 - val_loss: 0.5787
# Epoch 59: early stopping
# Restoring model weights from the end of the best epoch: 39.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9104 - loss: 0.2759
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9104 - loss: 0.2759
# Loss : 0.3687077760696411, Accuracy : 0.8960000276565552

# %%
X_train,X_val,X_test,y_train,y_val,y_test = get_train_val_test(X_logmel_aug.squeeze(3),Y_aug)
LSTM_model = get_model(X_train.shape[1:])
# LSTM_model.summary()


from datetime import datetime  
name = datetime.now().strftime("models/RAVDESS_lstm_aug_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=20,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]


LSTM_history = LSTM_model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       verbose=1,
                       callbacks=callbacks)


print(f"Loss : {LSTM_model.evaluate(X_test,y_test)[0]}, Accuracy : {LSTM_model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2925 - loss: 1.8095
# Epoch 1: val_loss improved from inf to 1.56622, saving model to models/RAVDESS_lstm_aug_07_10_2024_18_35_30.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - accuracy: 0.2937 - loss: 1.8061 - val_accuracy: 0.4016 - val_loss: 1.5662
# Epoch 2/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4113 - loss: 1.5116
# Epoch 2: val_loss improved from 1.56622 to 1.41713, saving model to models/RAVDESS_lstm_aug_07_10_2024_18_35_30.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.4114 - loss: 1.5115 - val_accuracy: 0.4472 - val_loss: 1.4171
# Epoch 3/1000
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.4665 - loss: 1.3647
# Epoch 3: val_loss improved from 1.41713 to 1.34637, saving model to models/RAVDESS_lstm_aug_07_10_2024_18_35_30.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.4663 - loss: 1.3652 - val_accuracy: 0.4816 - val_loss: 1.3464
# Epoch 4/1000
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5061 - loss: 1.2848
# Epoch 4: val_loss improved from 1.34637 to 1.27306, saving model to models/RAVDESS_lstm_aug_07_10_2024_18_35_30.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.5061 - loss: 1.2849 - val_accuracy: 0.4994 - val_loss: 1.2731
# Epoch 5/1000
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5396 - loss: 1.1774
# Epoch 5: val_loss improved from 1.27306 to 1.27248, saving model to models/RAVDESS_lstm_aug_07_10_2024_18_35_30.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.
val_loss did not improve from 0.68938
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9581 - loss: 0.1191 - val_accuracy: 0.8242 - val_loss: 0.7952
# Epoch 43/1000
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9683 - loss: 0.1050
# Epoch 43: val_loss did not improve from 0.68938
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9683 - loss: 0.1047 - val_accuracy: 0.8309 - val_loss: 0.7504
# Epoch 44/1000
# 111/113 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9656 - loss: 0.1030
# Epoch 44: val_loss did not improve from 0.68938
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 23ms/step - accuracy: 0.9655 - loss: 0.1035 - val_accuracy: 0.7887 - val_loss: 0.8568
# Epoch 45/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9242 - loss: 0.2402
# Epoch 45: val_loss did not improve from 0.68938
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9241 - loss: 0.2403 - val_accuracy: 0.8098 - val_loss: 0.7102
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 25.
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8393 - loss: 0.5854
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8393 - loss: 0.5854
# Loss : 0.5928413271903992, Accuracy : 0.8240000009536743

# %%
from sklearn.svm import SVC
X_train,X_val,X_test,y_train,y_val,y_test = get_train_val_test(X_logmel.squeeze(3),Y_not_aug)
X_train = X_train.reshape(X_train.shape[0],-1)
X_test = X_test.reshape(X_test.shape[0],-1)


SVC_model = SVC(kernel = 'rbf', gamma = 'auto', probability = True, verbose=True)


SVC_history = SVC_model.fit(X_train, np.argmax(y_train,axis=-1))
SVC_model.score(X_test,np.argmax(y_test,axis=-1))
# Out:
# [LibSVM]
# 0.552

# %%
from sklearn.svm import SVC
X_train,X_val,X_test,y_train,y_val,y_test = get_train_val_test(X_logmel_semi_aug.squeeze(3),Y_semi_aug)
X_train = X_train.reshape(X_train.shape[0],-1)
X_test = X_test.reshape(X_test.shape[0],-1)


SVC_model = SVC(kernel = 'rbf', gamma = 'auto', probability = True, verbose=True)


SVC_history = SVC_model.fit(X_train, np.argmax(y_train,axis=-1))
SVC_model.score(X_test,np.argmax(y_test,axis=-1))
# Out:
# [LibSVM]
# 0.712

# %%
from sklearn.svm import SVC
X_train,X_val,X_test,y_train,y_val,y_test = get_train_val_test(X_logmel_aug.squeeze(3),Y_aug)
X_train = X_train.reshape(X_train.shape[0],-1)
X_test = X_test.reshape(X_test.shape[0],-1)


SVC_model = SVC(kernel = 'rbf', gamma = 'auto', probability = True, verbose=True)


SVC_history = SVC_model.fit(X_train, np.argmax(y_train,axis=-1))
SVC_model.score(X_test,np.argmax(y_test,axis=-1))
# Out:
# [LibSVM]
# 0.726

# %% [markdown]
# ### Training mfccs

# %%
# extraction of the mfccs from the datasets - not aug
X_mfccs_k = np.array(not_aug_df.iloc[:, 4:30])
X_mfccs_k = np.array(X_mfccs_k.tolist())
# X_mfccs_k=scaler.fit_transform(X_mfccs_k.reshape(-1, X_mfccs_k.shape[-1])).reshape(X_mfccs_k.shape)
Y_mfccs_k = not_aug_df['label']

#reshape the data from 3D to 2D - not aug
X_mfccs_k=X_mfccs_k.reshape(X_mfccs_k.shape[0],X_mfccs_k.shape[1]*X_mfccs_k.shape[2])

# %%
#extraction of labels_id from datasets
Y_not_aug=not_aug_df['label_id']
Y_semi_aug=semi_aug_df['label_id']
Y_aug=aug_df['label_id']


X_mfccs = np.array(not_aug_df.iloc[:, 4:30]) 
X_mfccs = np.array(X_mfccs.tolist())
X_mfccs_semi_aug = np.array(semi_aug_df.iloc[:, 4:30])
X_mfccs_semi_aug=np.array(X_mfccs_semi_aug.tolist())
X_mfccs_aug = np.array(aug_df.iloc[:, 4:30])
X_mfccs_aug=np.array(X_mfccs_aug.tolist())


X_mfccs = np.reshape(X_mfccs, (X_mfccs.shape[0],X_mfccs.shape[1],X_mfccs.shape[2],1))
X_mfccs_semi_aug= np.reshape(X_mfccs_semi_aug, (X_mfccs_semi_aug.shape[0],X_mfccs_semi_aug.shape[1],X_mfccs_semi_aug.shape[2],1))
X_mfccs_aug= np.reshape(X_mfccs_aug, (X_mfccs_aug.shape[0],X_mfccs_aug.shape[1],X_mfccs_aug.shape[2],1))

# %%
from datetime import datetime  
name = datetime.now().strftime("models/augmented_vs_clean/SER_RAVDESS_mfccs_clean_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=10,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

X_train, X_val, X_test, y_train,  y_val, y_test = get_train_val_test(X_mfccs,Y_not_aug)

model = get_cnn((X_train.shape[1:]))
# model.summary()
history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.1675 - loss: 2.8416
# Epoch 1: val_loss improved from inf to 1.93378, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_clean_03_10_2024_17_38_30.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 250ms/step - accuracy: 0.1690 - loss: 2.8055 - val_accuracy: 0.1733 - val_loss: 1.9338
# Epoch 2/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step - accuracy: 0.2219 - loss: 1.9147
# Epoch 2: val_loss improved from 1.93378 to 1.90474, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_clean_03_10_2024_17_38_30.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.2220 - loss: 1.9145 - val_accuracy: 0.1956 - val_loss: 1.9047
# Epoch 3/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - accuracy: 0.2722 - loss: 1.8759
# Epoch 3: val_loss improved from 1.90474 to 1.84821, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_clean_03_10_2024_17_38_30.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 267ms/step - accuracy: 0.2723 - loss: 1.8751 - val_accuracy: 0.2489 - val_loss: 1.8482
# Epoch 4/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.2462 - loss: 1.8274
# Epoch 4: val_loss improved from 1.84821 to 1.83451, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_clean_03_10_2024_17_38_30.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 9s 327ms/step - accuracy: 0.2469 - loss: 1.8269 - val_accuracy: 0.2489 - val_loss: 1.8345
# Epoch 5/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.2792 - loss: 1.7693
# Epoch 5: val_loss did not improve from 1.83451
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 346ms/step - accuracy: 0.2781 - loss: 1.7718 - val_accuracy: 0.2311 - val_loss: 1.8728
# Epoch 6/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - accuracy: 0.2454 - loss: 1.8276
# Epoch 6: val_loss improved from 1.83451 to 1.80193, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_clean_03_10_2024_17_38_30.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 351ms/step - accuracy: 0.2465 - loss: 1.8261 - val_accuracy: 0.2578 - val_loss: 1.8019
# Epoch 7/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.2895 - loss: 1.7257
# Epoch 7: val_loss improved from 1.80193 to 1.77066, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_clean_03_10_2024_17_38_30.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 353ms/step - accuracy: 0.2890 - loss: 1.7270 - val_accuracy: 0.2667 - val_loss: 1.7707
# Epoch 8/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - accuracy: 0.2857 - loss: 1.7426
# Epoch 8: val_loss did not improve from 1.77066
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 350ms/step - accuracy: 0.2861 - loss: 1.7416 - val_accuracy: 0.2578 - val_loss: 1.8008
# Epoch 9/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.2800 - loss: 1.7466
# Epoch 9: val_loss did not improve from 1.77066
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 349ms/step - accuracy: 0.2800 - loss: 1.7455 - val_accuracy: 0.2533 - val_loss: 1.7805
# Epoch 10/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - accuracy: 0.3328 - loss: 1.6771
# Epoch 10: val_loss improved from 1.77066 to 1.73814, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_clean_03_10_2024_17_38_30.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 10s 354ms/step - accuracy: 0.3326 - loss: 1.6777 - val_accuracy: 0.2933 - val_loss: 1.7381
# Epoch 11/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step - accuracy: 0

# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.5787 - loss: 1.3489
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.5787 - loss: 1.3489
# Loss : 1.3220465183258057, Accuracy : 0.5653333067893982

# %%
from datetime import datetime  
name = datetime.now().strftime("models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=10,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

X_train, X_val, X_test, y_train,  y_val, y_test = get_train_val_test(X_mfccs_aug,Y_aug)

model = get_cnn((X_train.shape[1:]))
# model.summary()
history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.1564 - loss: 2.4315
# Epoch 1: val_loss improved from inf to 1.90303, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 45s 385ms/step - accuracy: 0.1566 - loss: 2.4282 - val_accuracy: 0.2269 - val_loss: 1.9030
# Epoch 2/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.2225 - loss: 1.8718
# Epoch 2: val_loss improved from 1.90303 to 1.75626, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 43s 380ms/step - accuracy: 0.2227 - loss: 1.8714 - val_accuracy: 0.3059 - val_loss: 1.7563
# Epoch 3/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.2694 - loss: 1.7743
# Epoch 3: val_loss improved from 1.75626 to 1.72813, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 43s 379ms/step - accuracy: 0.2694 - loss: 1.7742 - val_accuracy: 0.3137 - val_loss: 1.7281
# Epoch 4/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.3018 - loss: 1.7355
# Epoch 4: val_loss improved from 1.72813 to 1.69673, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 42s 372ms/step - accuracy: 0.3018 - loss: 1.7354 - val_accuracy: 0.2903 - val_loss: 1.6967
# Epoch 5/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.3207 - loss: 1.6734
# Epoch 5: val_loss did not improve from 1.69673
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 45s 403ms/step - accuracy: 0.3207 - loss: 1.6735 - val_accuracy: 0.3103 - val_loss: 1.7013
# Epoch 6/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3230 - loss: 1.6595
# Epoch 6: val_loss improved from 1.69673 to 1.58347, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 46s 405ms/step - accuracy: 0.3230 - loss: 1.6593 - val_accuracy: 0.3826 - val_loss: 1.5835
# Epoch 7/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.3610 - loss: 1.5539
# Epoch 7: val_loss did not improve from 1.58347
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 45s 403ms/step - accuracy: 0.3610 - loss: 1.5540 - val_accuracy: 0.3626 - val_loss: 1.6109
# Epoch 8/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4144 - loss: 1.4838
# Epoch 8: val_loss improved from 1.58347 to 1.51665, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 46s 403ms/step - accuracy: 0.4144 - loss: 1.4839 - val_accuracy: 0.4138 - val_loss: 1.5166
# Epoch 9/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.4408 - loss: 1.4380
# Epoch 9: val_loss improved from 1.51665 to 1.47540, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 76s 354ms/step - accuracy: 0.4407 - loss: 1.4382 - val_accuracy: 0.4194 - val_loss: 1.4754
# Epoch 10/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.4387 - loss: 1.4198
# Epoch 10: val_loss did not improve from 1.47540
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 45s 403ms/step - accuracy: 0.4388 - loss: 1.4196 - val_accuracy: 0.3993 - val_loss: 1.5491
# Epoch 11/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step - accuracy: 0.4305 - loss: 1.4251
# Epoch 11: val_loss improved from 1.47540 to 1.45610, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 45s 402ms/step - accuracy: 0.4306 - loss: 1.4249 - val_accuracy: 0.4283 - val_loss: 1.4561
# Epoch 12/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step - accuracy: 0.4835 - loss: 1.3107
# Epoch 12: val_loss improved from 1.45610 to 1.44390, saving model to models/augmented_vs_clean/SER_RAVDESS_mfccs_aug_03_10_2024_18_13_49.keras
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 46s 406ms/step - accuracy: 0.4834 - loss: 1.3109 - val_accuracy: 0.4383 - val_loss: 1.4439
# Epoch 13/1000
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.4798 - loss: 1.3221
# Epoch 13: val_loss did not improve from 1.44390
# 113/113 ━━━━━━━━━━━━━━━━━━━━