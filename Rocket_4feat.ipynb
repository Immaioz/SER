# %%
import os
import re
import sys
import librosa
from random import shuffle
import numpy as np
from typing import Tuple, Union
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import joblib
import keras

from keras import models, layers
from tqdm import tqdm

# %%
data_df = pd.read_csv("EMOVO_dataset/data.csv")

# %%
def get_max_min(files):
    min_, max_ = 100, 0
    for file in files:
        sound_file, samplerate = librosa.load(file)
        t = sound_file.shape[0] / samplerate
        if t < min_:
            min_ = t
        if t > max_:
            max_ = t

    return max_, min_

# %%
def extract_new(file,pad):
    X, sample_rate = librosa.load(file)
    max_ = X.shape[0] / sample_rate
    if max_ < pad:
        length = (pad * sample_rate) -  (X.shape[0] / sample_rate)
        X = librosa.util.pad_center(X, size = length, mode = 'constant')   
    stft = np.abs(librosa.stft(X, n_fft=662, hop_length=221))
    # result = np.array([])
    result = []

    # mfccs = np.mean(.T, axis=0)

    mfccs = librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=13, n_fft=662, hop_length=221)

    # result = np.hstack((result, mfccs))
    result.append((mfccs))

    # chroma = np.mean(.T, axis=0)
    chroma = librosa.feature.chroma_stft(S=stft, sr=sample_rate, n_fft=662, hop_length=221)
    # result = np.hstack((result, chroma))
    result.append(chroma)

    # mel = np.mean(.T, axis=0) 
    mel = librosa.feature.melspectrogram(y=X, sr=sample_rate, n_fft=662, hop_length=221)
    # result = np.hstack((result, mel))
    result.append(mel)
    
    # contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T, axis=0)
    contrast = librosa.feature.spectral_contrast(S=stft, sr=sample_rate, n_fft=662, hop_length=221)
    # result = np.hstack((result, contrast))
    result.append(contrast)

    # tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)
    # result = np.hstack((result, tonnetz))
    return result

# %%
max, min = get_max_min('EMOVO_dataset/'+data_df.file_name)
train_data = pd.DataFrame(columns=['filename', 'features', 'label'])
output_length = int(np.ceil(max * (22050) / (221)))
features = []
for index, file in zip(data_df.index, data_df.file_name):
    train_data.loc[index] = [file, extract_new('EMOVO_dataset/'+file, max), data_df.label[index]]

# %%
X1 = np.empty((0, output_length))
X2 = np.empty((0, output_length))
X3 = np.empty((0, output_length))
X4 = np.empty((0, output_length))

for data in tqdm(train_data["features"]):
    X1 = np.vstack((X1, data[0]))
    X2 = np.vstack((X2, data[1]))
    X3 = np.vstack((X3, data[2]))
    X4 = np.vstack((X4, data[3]))

X1 = X1.reshape(len(data_df),output_length,-1)
X2 = X2.reshape(len(data_df),output_length,-1)
X3 = X3.reshape(len(data_df),output_length,-1)
X4 = X4.reshape(len(data_df),output_length,-1)
# Out:
#   0%|          | 0/588 [00:00<?, ?it/s]
# 100%|██████████| 588/588 [03:22<00:00,  2.90it/s]

# %%
data_classes = (list((train_data["label"].unique())))
Y = keras.utils.to_categorical(list((train_data["label"].apply(data_classes.index))))
# X = np.stack(train_data["features"])
X = np.expand_dims(np.concatenate([X1,X2,X3,X4], axis=2),3)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=22)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=22)

# %%
def get_cnn(input_shape):
    model = keras.Sequential()

    model.add(keras.layers.Input(shape=input_shape))

    model.add(keras.layers.Conv2D(256, 3, activation='relu' ))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))

    model.add(keras.layers.Conv2D(128, 3, activation='relu'))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))


    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))

    model.add(keras.layers.GlobalAveragePooling2D())
    model.add(keras.layers.Dense(1024, activation='relu'))
    
    model.add(keras.layers.Dense(256, activation='relu'))
    model.add(keras.layers.Dense(64, activation='relu'))

    model.add(keras.layers.Dense(7, activation='softmax'))

    optimzer = keras.optimizers.Adam()
    model.compile(loss='categorical_crossentropy', optimizer=optimzer, metrics=['accuracy'])

    return model

# %%
from datetime import datetime  
name = datetime.now().strftime("models/EMOVO_4feat_CNN_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=5,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

model = get_cnn((X_train.shape[1:]))

# %%
history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.1524 - loss: 1.9767
# Epoch 1: val_loss improved from inf to 1.94252, saving model to models/EMOVO_4feat_CNN_08_10_2024_10_25_41.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 193s 13s/step - accuracy: 0.1501 - loss: 1.9761 - val_accuracy: 0.1792 - val_loss: 1.9425
# Epoch 2/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.1578 - loss: 1.9429
# Epoch 2: val_loss did not improve from 1.94252
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 185s 13s/step - accuracy: 0.1572 - loss: 1.9432 - val_accuracy: 0.1132 - val_loss: 1.9463
# Epoch 3/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12s/step - accuracy: 0.1801 - loss: 1.9464
# Epoch 3: val_loss did not improve from 1.94252
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 186s 13s/step - accuracy: 0.1783 - loss: 1.9464 - val_accuracy: 0.1132 - val_loss: 1.9473
# Epoch 4/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.1552 - loss: 1.9454
# Epoch 4: val_loss did not improve from 1.94252
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 191s 14s/step - accuracy: 0.1551 - loss: 1.9454 - val_accuracy: 0.1132 - val_loss: 1.9476
# Epoch 5/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.1352 - loss: 1.9459
# Epoch 5: val_loss did not improve from 1.94252
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 198s 14s/step - accuracy: 0.1361 - loss: 1.9459 - val_accuracy: 0.1132 - val_loss: 1.9477
# Epoch 6/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.1438 - loss: 1.9446
# Epoch 6: val_loss did not improve from 1.94252
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 189s 14s/step - accuracy: 0.1446 - loss: 1.9445 - val_accuracy: 0.1132 - val_loss: 1.9486
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 1.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.0773 - loss: 1.9504
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 5s 2s/step - accuracy: 0.0773 - loss: 1.9504
# Loss : 1.9510806798934937, Accuracy : 0.08474576473236084

# %%
import keras
from keras import layers, models

def get_model(input_shape):
    inputs = layers.Input(shape=input_shape)
    encoder = layers.LSTM(128)(inputs)
    drop = layers.Dropout(0.3)(encoder)
    hidden = layers.Dense(32, activation='relu')(drop)
    outputs = layers.Dense(7, activation='softmax')(hidden)
    
    model = models.Model(inputs, outputs)
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=["accuracy"])

    return model

# %%
X_train, X_test, y_train, y_test = train_test_split(X.squeeze(3), Y, test_size=0.1, random_state=22)
# X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=22)
LSTM_model = get_model(X_train.shape[1:])
# LSTM_model.summary()


from datetime import datetime  
name = datetime.now().strftime("models/EMOVO_4feat_LSTM_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=10,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]


LSTM_history = LSTM_model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       verbose=1,
                       callbacks=callbacks)
# Out:
# Epoch 1/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.1173 - loss: 2.0442
# Epoch 1: val_loss improved from inf to 1.89372, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 458ms/step - accuracy: 0.1187 - loss: 2.0412 - val_accuracy: 0.2358 - val_loss: 1.8937
# Epoch 2/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.2027 - loss: 1.9175
# Epoch 2: val_loss improved from 1.89372 to 1.82492, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 443ms/step - accuracy: 0.2015 - loss: 1.9177 - val_accuracy: 0.2264 - val_loss: 1.8249
# Epoch 3/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.2127 - loss: 1.8922
# Epoch 3: val_loss improved from 1.82492 to 1.79454, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 428ms/step - accuracy: 0.2123 - loss: 1.8916 - val_accuracy: 0.2642 - val_loss: 1.7945
# Epoch 4/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.2158 - loss: 1.8853
# Epoch 4: val_loss improved from 1.79454 to 1.77065, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 511ms/step - accuracy: 0.2160 - loss: 1.8850 - val_accuracy: 0.2925 - val_loss: 1.7706
# Epoch 5/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.2582 - loss: 1.8406
# Epoch 5: val_loss did not improve from 1.77065
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 488ms/step - accuracy: 0.2571 - loss: 1.8417 - val_accuracy: 0.3113 - val_loss: 1.8017
# Epoch 6/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.2083 - loss: 1.8389
# Epoch 6: val_loss improved from 1.77065 to 1.75346, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 430ms/step - accuracy: 0.2084 - loss: 1.8397 - val_accuracy: 0.2547 - val_loss: 1.7535
# Epoch 7/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.2535 - loss: 1.8023
# Epoch 7: val_loss improved from 1.75346 to 1.73969, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 587ms/step - accuracy: 0.2544 - loss: 1.8032 - val_accuracy: 0.3491 - val_loss: 1.7397
# Epoch 8/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step - accuracy: 0.2146 - loss: 1.8415
# Epoch 8: val_loss improved from 1.73969 to 1.73789, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 504ms/step - accuracy: 0.2150 - loss: 1.8426 - val_accuracy: 0.3396 - val_loss: 1.7379
# Epoch 9/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.2455 - loss: 1.8348
# Epoch 9: val_loss improved from 1.73789 to 1.72576, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.2456 - loss: 1.8345 - val_accuracy: 0.3774 - val_loss: 1.7258
# Epoch 10/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.3046 - loss: 1.7751
# Epoch 10: val_loss improved from 1.72576 to 1.71079, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 433ms/step - accuracy: 0.3024 - loss: 1.7780 - val_accuracy: 0.3396 - val_loss: 1.7108
# Epoch 11/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.1902 - loss: 1.8941
# Epoch 11: val_loss improved from 1.71079 to 1.69133, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 423ms/step - accuracy: 0.1922 - loss: 1.8914 - val_accuracy: 0.3774 - val_loss: 1.6913
# Epoch 12/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.2261 - loss: 1.8502
# Epoch 12: val_loss improved from 1.69133 to 1.65885, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 419ms/step - accuracy: 0.2277 - loss: 1.8477 - val_accuracy: 0.3491 - val_loss: 1.6588
# Epoch 13/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - accuracy: 0.2471 - loss: 1.8178
# Epoch 13: val_loss improved from 1.65885 to 1.65399, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 547ms/step - accuracy: 0.2486 - loss: 1.8166 - val_accuracy: 0.3585 - val_loss: 1.6540
# Epoch 14/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.3028 - loss: 1.8195
# Epoch 14: val_loss improved from 1.65399 to 1.64781, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 435ms/step - accuracy: 0.3017 - loss: 1.8184 - val_accuracy: 0.3585 - val_loss: 1.6478
# Epoch 15/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 454ms/step - accuracy: 0.2812 - loss: 1.7854
# Epoch 15: val_loss improved from 1.64781 to 1.62878, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 504ms/step - accuracy: 0.2808 - loss: 1.7853 - val_accuracy: 0.4151 - val_loss: 1.6288
# Epoch 16/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.2930 - loss: 1.7475
# Epoch 16: val_loss did not improve from 1.62878
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 419ms/step - accuracy: 0.2926 - loss: 1.7497 - val_accuracy: 0.4057 - val_loss: 1.6388
# Epoch 17/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.2639 - loss: 1.7608
# Epoch 17: val_loss improved from 1.62878 to 1.61711, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 574ms/step - accuracy: 0.2639 - loss: 1.7609 - val_accuracy: 0.4057 - val_loss: 1.6171
# Epoch 18/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step - accuracy: 0.2850 - loss: 1.7360
# Epoch 18: val_loss did not improve from 1.61711
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 483ms/step - accuracy: 0.2852 - loss: 1.7376 - val_accuracy: 0.3491 - val_loss: 1.6238
# Epoch 19/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.2864 - loss: 1.7262
# Epoch 19: val_loss improved from 1.61711 to 1.56823, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 474ms/step - accuracy: 0.2863 - loss: 1.7266 - val_accuracy: 0.3774 - val_loss: 1.5682
# Epoch 20/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step - accuracy: 0.2776 - loss: 1.7490
# Epoch 20: val_loss improved from 1.56823 to 1.53803, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 427ms/step - accuracy: 0.2778 - loss: 1.7474 - val_accuracy: 0.4057 - val_loss: 1.5380
# Epoch 21/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.3428 - loss: 1.6789
# Epoch 21: val_loss did not improve from 1.53803
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 446ms/step - accuracy: 0.3400 - loss: 1.6824 - val_accuracy: 0.3868 - val_loss: 1.5604
# Epoch 22/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.2900 - loss: 1.6944
# Epoch 22: val_loss improved from 1.53803 to 1.53061, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 446ms/step - accuracy: 0.2886 - loss: 1.6961 - val_accuracy: 0.4528 - val_loss: 1.5306
# Epoch 23/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.2807 - loss: 1.7044
# Epoch 23: val_loss improved from 1.53061 to 1.50489, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 435ms/step - accuracy: 0.2815 - loss: 1.7043 - val_accuracy: 0.4623 - val_loss: 1.5049
# Epoch 24/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 443ms/step - accuracy: 0.2893 - loss: 1.7027
# Epoch 24: val_loss improved from 1.50489 to 1.50280, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 479ms/step - accuracy: 0.2892 - loss: 1.7026 - val_accuracy: 0.4340 - val_loss: 1.5028
# Epoch 25/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step - accuracy: 0.3549 - loss: 1.6333
# Epoch 25: val_loss improved from 1.50280 to 1.49797, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 468ms/step - accuracy: 0.3542 - loss: 1.6357 - val_accuracy: 0.4340 - val_loss: 1.4980
# Epoch 26/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.3543 - loss: 1.6097
# Epoch 26: val_loss improved from 1.49797 to 1.49018, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 492ms/step - accuracy: 0.3521 - loss: 1.6114 - val_accuracy: 0.4245 - val_loss: 1.4902
# Epoch 27/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.3765 - loss: 1.5835
# Epoch 27: val_loss did not improve from 1.49018
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 569ms/step - accuracy: 0.3759 - loss: 1.5848 - val_accuracy: 0.3962 - val_loss: 1.5364
# Epoch 28/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.2959 - loss: 1.6537
# Epoch 28: val_loss improved from 1.49018 to 1.45440, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 439ms/step - accuracy: 0.2981 - loss: 1.6515 - val_accuracy: 0.4434 - val_loss: 1.4544
# Epoch 29/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.3788 - loss: 1.5291
# Epoch 29: val_loss did not improve from 1.45440
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 416ms/step - accuracy: 0.3768 - loss: 1.5313 - val_accuracy: 0.3396 - val_loss: 1.5217
# Epoch 30/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.3972 - loss: 1.5293
# Epoch 30: val_loss improved from 1.45440 to 1.40558, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 490ms/step - accuracy: 0.3953 - loss: 1.5303 - val_accuracy: 0.4434 - val_loss: 1.4056
# Epoch 31/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.3895 - loss: 1.5464
# Epoch 31: val_loss improved from 1.40558 to 1.36663, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 422ms/step - accuracy: 0.3887 - loss: 1.5459 - val_accuracy: 0.4151 - val_loss: 1.3666
# Epoch 32/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.3669 - loss: 1.5441
# Epoch 32: val_loss did not improve from 1.36663
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 416ms/step - accuracy: 0.3670 - loss: 1.5445 - val_accuracy: 0.4151 - val_loss: 1.4157
# Epoch 33/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.3659 - loss: 1.5086
# Epoch 33: val_loss improved from 1.36663 to 1.35767, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 417ms/step - accuracy: 0.3652 - loss: 1.5111 - val_accuracy: 0.5000 - val_loss: 1.3577
# Epoch 34/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.3713 - loss: 1.5311
# Epoch 34: val_loss improved from 1.35767 to 1.32708, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 431ms/step - accuracy: 0.3714 - loss: 1.5297 - val_accuracy: 0.3962 - val_loss: 1.3271
# Epoch 35/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 368ms/step - accuracy: 0.4079 - loss: 1.4590
# Epoch 35: val_loss improved from 1.32708 to 1.26892, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 401ms/step - accuracy: 0.4078 - loss: 1.4574 - val_accuracy: 0.4811 - val_loss: 1.2689
# Epoch 36/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.4256 - loss: 1.4033
# Epoch 36: val_loss improved from 1.26892 to 1.26028, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 422ms/step - accuracy: 0.4247 - loss: 1.4046 - val_accuracy: 0.4906 - val_loss: 1.2603
# Epoch 37/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.4512 - loss: 1.3407
# Epoch 37: val_loss improved from 1.26028 to 1.23594, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 430ms/step - accuracy: 0.4494 - loss: 1.3434 - val_accuracy: 0.4528 - val_loss: 1.2359
# Epoch 38/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.4462 - loss: 1.3438
# Epoch 38: val_loss did not improve from 1.23594
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 422ms/step - accuracy: 0.4459 - loss: 1.3446 - val_accuracy: 0.5283 - val_loss: 1.2858
# Epoch 39/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 386ms/step - accuracy: 0.4383 - loss: 1.3892
# Epoch 39: val_loss improved from 1.23594 to 1.20682, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 424ms/step - accuracy: 0.4377 - loss: 1.3901 - val_accuracy: 0.5094 - val_loss: 1.2068
# Epoch 40/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.4292 - loss: 1.3276
# Epoch 40: val_loss did not improve from 1.20682
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 508ms/step - accuracy: 0.4307 - loss: 1.3266 - val_accuracy: 0.4528 - val_loss: 1.2182
# Epoch 41/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step - accuracy: 0.4760 - loss: 1.2888
# Epoch 41: val_loss improved from 1.20682 to 1.16899, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 496ms/step - accuracy: 0.4770 - loss: 1.2865 - val_accuracy: 0.5660 - val_loss: 1.1690
# Epoch 42/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.4737 - loss: 1.2862
# Epoch 42: val_loss did not improve from 1.16899
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 9s 512ms/step - accuracy: 0.4726 - loss: 1.2886 - val_accuracy: 0.5189 - val_loss: 1.2076
# Epoch 43/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.4715 - loss: 1.2432
# Epoch 43: val_loss improved from 1.16899 to 1.16739, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 437ms/step - accuracy: 0.4715 - loss: 1.2445 - val_accuracy: 0.4717 - val_loss: 1.1674
# Epoch 44/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.4588 - loss: 1.2438
# Epoch 44: val_loss did not improve from 1.16739
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 443ms/step - accuracy: 0.4586 - loss: 1.2445 - val_accuracy: 0.4623 - val_loss: 1.2367
# Epoch 45/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step - accuracy: 0.4268 - loss: 1.3096
# Epoch 45: val_loss improved from 1.16739 to 1.10201, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 434ms/step - accuracy: 0.4276 - loss: 1.3076 - val_accuracy: 0.5472 - val_loss: 1.1020
# Epoch 46/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 635ms/step - accuracy: 0.5851 - loss: 1.1367
# Epoch 46: val_loss improved from 1.10201 to 1.04616, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 12s 698ms/step - accuracy: 0.5831 - loss: 1.1391 - val_accuracy: 0.5849 - val_loss: 1.0462
# Epoch 47/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.5227 - loss: 1.1728
# Epoch 47: val_loss improved from 1.04616 to 1.01070, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 589ms/step - accuracy: 0.5229 - loss: 1.1722 - val_accuracy: 0.5849 - val_loss: 1.0107
# Epoch 48/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.5463 - loss: 1.2028
# Epoch 48: val_loss improved from 1.01070 to 0.94364, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 457ms/step - accuracy: 0.5469 - loss: 1.1995 - val_accuracy: 0.6604 - val_loss: 0.9436
# Epoch 49/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.6058 - loss: 1.0277
# Epoch 49: val_loss improved from 0.94364 to 0.89189, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 456ms/step - accuracy: 0.6046 - loss: 1.0299 - val_accuracy: 0.6887 - val_loss: 0.8919
# Epoch 50/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.6209 - loss: 1.0155
# Epoch 50: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 10s 431ms/step - accuracy: 0.6183 - loss: 1.0174 - val_accuracy: 0.5660 - val_loss: 0.9513
# Epoch 51/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.4935 - loss: 1.1441
# Epoch 51: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 456ms/step - accuracy: 0.4949 - loss: 1.1427 - val_accuracy: 0.6132 - val_loss: 0.9295
# Epoch 52/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.6103 - loss: 1.0046
# Epoch 52: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.6099 - loss: 1.0055 - val_accuracy: 0.6415 - val_loss: 0.9275
# Epoch 53/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.5950 - loss: 1.0177
# Epoch 53: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 453ms/step - accuracy: 0.5962 - loss: 1.0169 - val_accuracy: 0.6321 - val_loss: 0.9381
# Epoch 54/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.5788 - loss: 1.0186
# Epoch 54: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 431ms/step - accuracy: 0.5782 - loss: 1.0211 - val_accuracy: 0.5660 - val_loss: 0.9984
# Epoch 55/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.6302 - loss: 0.9426
# Epoch 55: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 385ms/step - accuracy: 0.6286 - loss: 0.9458 - val_accuracy: 0.6038 - val_loss: 0.9057
# Epoch 56/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 392ms/step - accuracy: 0.5947 - loss: 1.0162
# Epoch 56: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 428ms/step - accuracy: 0.5954 - loss: 1.0137 - val_accuracy: 0.6604 - val_loss: 0.8981
# Epoch 57/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step - accuracy: 0.6551 - loss: 0.9178
# Epoch 57: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 435ms/step - accuracy: 0.6536 - loss: 0.9199 - val_accuracy: 0.6887 - val_loss: 0.8931
# Epoch 58/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.6030 - loss: 0.9768
# Epoch 58: val_loss did not improve from 0.89189
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 454ms/step - accuracy: 0.6014 - loss: 0.9795 - val_accuracy: 0.5943 - val_loss: 0.9516
# Epoch 59/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 379ms/step - accuracy: 0.5697 - loss: 1.0803
# Epoch 59: val_loss improved from 0.89189 to 0.83861, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 7s 418ms/step - accuracy: 0.5718 - loss: 1.0767 - val_accuracy: 0.7075 - val_loss: 0.8386
# Epoch 60/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.6371 - loss: 0.9088
# Epoch 60: val_loss improved from 0.83861 to 0.78810, saving model to models/EMOVO_4feat_LSTM_08_10_2024_10_45_21.keras
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 8s 452ms/step - accuracy: 0.6371 - loss: 0.9095 - val_accuracy: 0.7264 - val_loss: 0.7881
# Epoch 61/1000
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0
")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - accuracy: 0.2850 - loss: 5.3449
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 219ms/step - accuracy: 0.2850 - loss: 5.3449
# Loss : 5.528655052185059, Accuracy : 0.2711864411830902

# %%
from sklearn.svm import SVC

X_train, X_test, y_train, y_test = train_test_split(X.squeeze(3), Y, test_size=0.1, random_state=22)

X_train = X_train.reshape(X_train.shape[0],-1)
X_test = X_test.reshape(X_test.shape[0],-1)

SVC_model = SVC(kernel = 'rbf', gamma = 'auto', probability = True, verbose=True)

SVC_history = SVC_model.fit(X_train, np.argmax(y_train,axis=-1))
SVC_model.score(X_test,np.argmax(y_test,axis=-1))
# Out:
# [LibSVM]

# %%
X[0].shape
# Out:
# (1397, 160, 1)

# %%
def obtain_df(X):
    X_df = pd.DataFrame(columns=['filename', 'features', 'label'])

    for index, file in tqdm(zip(data_df.index, data_df.file_name)):
        X_df.loc[index] = [file, pd.Series(X[index].flatten()), data_df.label[index]]
    X = pd.DataFrame(X_df["features"])
    return X

from sktime.transformations.panel.rocket import Rocket

def get_rocket(X):
    trf = Rocket(num_kernels=512) 
    trf.fit(X) 
    X_ = trf.transform(X)
    return X_

# %%
X1_ = get_rocket(obtain_df(X1)).to_numpy()
# Out:
# 588it [00:02, 281.29it/s]

# %%
X2_ = get_rocket(obtain_df(X2)).to_numpy()
X3_ = get_rocket(obtain_df(X3)).to_numpy()
X4_ = get_rocket(obtain_df(X4)).to_numpy()
# Out:
# 588it [00:01, 315.98it/s]
# 588it [00:08, 71.45it/s]
# 588it [00:00, 1635.87it/s]

# %%
import tensorflow as tf
from keras.utils import to_categorical

data_classes = (list((train_data["label"].unique())))
Y = to_categorical(list((train_data["label"].apply(data_classes.index))))
# X = np.stack(train_data["features"])
X_ = np.hstack([X1_,X2_,X3_,X4_])

X_train_, X_test_, y_train_, y_test_ = train_test_split(X_, Y, test_size=0.1, random_state=22)
X_train_, X_val_, y_train_, y_val_ = train_test_split(X_train_, y_train_, test_size=0.2, random_state=22)

# %%
X_train.shape
# Out:
# (423, 1397, 160, 1)

# %%
from datetime import datetime  
name = datetime.now().strftime("models/EMOVO_rocket_CNN_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=5,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

model = get_cnn((X_train.shape[1:]))

# %%
history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - accuracy: 0.1156 - loss: 2.0481
# Epoch 1: val_loss improved from inf to 1.95082, saving model to models/EMOVO_rocket_CNN_08_10_2024_12_30_32.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 267s 17s/step - accuracy: 0.1159 - loss: 2.0451 - val_accuracy: 0.1132 - val_loss: 1.9508
# Epoch 2/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15s/step - accuracy: 0.1393 - loss: 1.9446
# Epoch 2: val_loss improved from 1.95082 to 1.94794, saving model to models/EMOVO_rocket_CNN_08_10_2024_12_30_32.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 215s 15s/step - accuracy: 0.1398 - loss: 1.9447 - val_accuracy: 0.1226 - val_loss: 1.9479
# Epoch 3/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.1324 - loss: 1.9466
# Epoch 3: val_loss improved from 1.94794 to 1.94787, saving model to models/EMOVO_rocket_CNN_08_10_2024_12_30_32.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 214s 15s/step - accuracy: 0.1333 - loss: 1.9465 - val_accuracy: 0.1132 - val_loss: 1.9479
# Epoch 4/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15s/step - accuracy: 0.1477 - loss: 1.9458
# Epoch 4: val_loss did not improve from 1.94787
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 215s 15s/step - accuracy: 0.1472 - loss: 1.9458 - val_accuracy: 0.1132 - val_loss: 1.9488
# Epoch 5/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15s/step - accuracy: 0.1553 - loss: 1.9434
# Epoch 5: val_loss improved from 1.94787 to 1.94626, saving model to models/EMOVO_rocket_CNN_08_10_2024_12_30_32.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 219s 16s/step - accuracy: 0.1552 - loss: 1.9433 - val_accuracy: 0.1132 - val_loss: 1.9463
# Epoch 6/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15s/step - accuracy: 0.1616 - loss: 1.9418
# Epoch 6: val_loss improved from 1.94626 to 1.93995, saving model to models/EMOVO_rocket_CNN_08_10_2024_12_30_32.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 221s 16s/step - accuracy: 0.1622 - loss: 1.9420 - val_accuracy: 0.1792 - val_loss: 1.9399
# Epoch 7/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13s/step - accuracy: 0.1514 - loss: 1.9425
# Epoch 7: val_loss improved from 1.93995 to 1.92047, saving model to models/EMOVO_rocket_CNN_08_10_2024_12_30_32.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 200s 14s/step - accuracy: 0.1522 - loss: 1.9420 - val_accuracy: 0.1981 - val_loss: 1.9205
# Epoch 8/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.1266 - loss: 1.9206
# Epoch 8: val_loss did not improve from 1.92047
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 203s 14s/step - accuracy: 0.1278 - loss: 1.9203 - val_accuracy: 0.2358 - val_loss: 1.9344
# Epoch 9/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14s/step - accuracy: 0.2425 - loss: 1.8957
# Epoch 9: val_loss improved from 1.92047 to 1.84257, saving model to models/EMOVO_rocket_CNN_08_10_2024_12_30_32.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 213s 15s/step - accuracy: 0.2426 - loss: 1.8959 - val_accuracy: 0.2264 - val_loss: 1.8426
# Epoch 10/1000
#  1/14 ━━━━━━━━━━━━━━━━━━━━ 3:39 17s/step - accuracy: 0.0312 - loss: 1.9563
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 history = model.fit(X_train, y_train,
#       2                        validation_data=(X_val,y_val),
#       3                        batch_size=32,
#       4                        epochs=1000,
#       5                        callbacks=callbacks)
#       8 print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:320, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     318 for step, iterator in epoch_iterator.enumerate_epoch():
#     319     callbacks.on_train_batch_begin(step)
# --> 320     logs = self.train_function(iterator)
#     321     logs = self._pythonify_logs(logs)
#     322     callbacks.on_train_batch_end(step, logs)
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\eager\context.py:1552, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1550 cancellation_context = cancellation.context()
#    1551 if cancellation_context is None:
# -> 1552   outputs = execute.execute(
#    1553       name.decode("utf-8"),
#    1554       num_outputs=num_outputs,
#    1555       inputs=tensor_inputs,
#    1556       attrs=attrs,
#    1557       ctx=self,
#    1558   )
#    1559 else:
#    1560   outputs = execute.execute_with_cancellation(
#    1561       name.decode("utf-8"),
#    1562       num_outputs=num_outputs,
#    (...)
#    1566       cancellation_manager=cancellation_context,
#    1567   )
#
# File c:\Users\anton\Documents\PhD\Speech_Emotion_Recognition\EMOVO_dataset\.venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# # LSTM

# %%
from keras import layers, models
def get_model(X_train):
    inputs = layers.Input(shape=(X_train.shape[1],1))
    encoder = layers.LSTM(128)(inputs)
    drop = layers.Dropout(0.3)(encoder)
    hidden = layers.Dense(32, activation='relu')(drop)
    outputs = layers.Dense(7, activation='softmax')(hidden)
    
    model = models.Model(inputs, outputs)
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=["accuracy"])

    return model

# %%
LSTM_model = get_model(X_train)
LSTM_model.summary()


from datetime import datetime  
name = datetime.now().strftime("ser_lstm_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=20,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]


LSTM_history = LSTM_model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       verbose=1,
                       callbacks=callbacks)


print(f"Loss : {LSTM_model.evaluate(X_test,y_test)[0]}, Accuracy : {LSTM_model.evaluate(X_test,y_test)[1]}")
# Out:
# Model: "functional_30"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 197, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,919 (277.03 KB)
#  Trainable params: 70,919 (277.03 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.1444 - loss: 2.0246 - val_accuracy: 0.1226 - val_loss: 1.9662
# Epoch 2/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1358 - loss: 1.9650 - val_accuracy: 0.1132 - val_loss: 1.9588
# Epoch 3/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1250 - loss: 1.9794 - val_accuracy: 0.0755 - val_loss: 1.9632
# Epoch 4/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.1612 - loss: 1.9545 - val_accuracy: 0.0755 - val_loss: 1.9591
# Epoch 5/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1323 - loss: 1.9667 - val_accuracy: 0.1132 - val_loss: 1.9597
# Epoch 6/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.1600 - loss: 1.9467 - val_accuracy: 0.1132 - val_loss: 1.9565
# Epoch 7/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.1384 - loss: 1.9565 - val_accuracy: 0.1132 - val_loss: 1.9457
# Epoch 8/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1179 - loss: 1.9656 - val_accuracy: 0.2075 - val_loss: 1.9394
# Epoch 9/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1354 - loss: 1.9533 - val_accuracy: 0.1981 - val_loss: 1.9413
# Epoch 10/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.0976 - loss: 1.9529 - val_accuracy: 0.1792 - val_loss: 1.9365
# Epoch 11/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1708 - loss: 1.9347 - val_accuracy: 0.1132 - val_loss: 1.9431
# Epoch 12/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1985 - loss: 1.9407 - val_accuracy: 0.2547 - val_loss: 1.9386
# Epoch 13/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1407 - loss: 1.9531 - val_accuracy: 0.2453 - val_loss: 1.9354
# Epoch 14/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1801 - loss: 1.9452 - val_accuracy: 0.2170 - val_loss: 1.9425
# Epoch 15/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1715 - loss: 1.9403 - val_accuracy: 0.1132 - val_loss: 1.9369
# Epoch 16/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1908 - loss: 1.9246 - val_accuracy: 0.2453 - val_loss: 1.9184
# Epoch 17/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2050 - loss: 1.9299 - val_accuracy: 0.2075 - val_loss: 1.8976
# Epoch 18/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2403 - loss: 1.9029 - val_accuracy: 0.1981 - val_loss: 1.9190
# Epoch 19/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.2199 - loss: 1.9140 - val_accuracy: 0.1698 - val_loss: 1.9301
# Epoch 20/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1744 - loss: 1.9356 - val_accuracy: 0.2736 - val_loss: 1.8976
# Epoch 21/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2061 - loss: 1.8986 - val_accuracy: 0.3019 - val_loss: 1.8549
# Epoch 22/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2433 - loss: 1.8718 - val_accuracy: 0.2642 - val_loss: 1.8036
# Epoch 23/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1889 - loss: 1.8811 - val_accuracy: 0.3208 - val_loss: 1.7960
# Epoch 24/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2215 - loss: 1.8665 - val_accuracy: 0.2642 - val_loss: 1.7973
# Epoch 25/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2132 - loss: 1.8784 - val_accuracy: 0.2075 - val_loss: 1.8817
# Epoch 26/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.2275 - loss: 1.8649 - val_accuracy: 0.3302 - val_loss: 1.7722
# Epoch 27/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.
1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2837 - loss: 1.6832 - val_accuracy: 0.3491 - val_loss: 1.6598
# Epoch 126/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3440 - loss: 1.6728 - val_accuracy: 0.3679 - val_loss: 1.6611
# Epoch 127/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2953 - loss: 1.6937 - val_accuracy: 0.3679 - val_loss: 1.6684
# Epoch 128/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3546 - loss: 1.6537 - val_accuracy: 0.2736 - val_loss: 1.7115
# Epoch 129/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2971 - loss: 1.7060 - val_accuracy: 0.3396 - val_loss: 1.6523
# Epoch 130/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3466 - loss: 1.6510 - val_accuracy: 0.3396 - val_loss: 1.6615
# Epoch 131/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3447 - loss: 1.6990 - val_accuracy: 0.3113 - val_loss: 1.7125
# Epoch 132/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3181 - loss: 1.7184 - val_accuracy: 0.3585 - val_loss: 1.6541
# Epoch 133/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3135 - loss: 1.7045 - val_accuracy: 0.3679 - val_loss: 1.6593
# Epoch 134/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3300 - loss: 1.6748 - val_accuracy: 0.3396 - val_loss: 1.6924
# Epoch 135/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3016 - loss: 1.6665 - val_accuracy: 0.3585 - val_loss: 1.6553
# Epoch 136/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3452 - loss: 1.6810 - val_accuracy: 0.3208 - val_loss: 1.6520
# Epoch 137/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3579 - loss: 1.6743 - val_accuracy: 0.3679 - val_loss: 1.6516
# Epoch 137: early stopping
# Restoring model weights from the end of the best epoch: 117.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2641 - loss: 1.6817
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2641 - loss: 1.6817
# Loss : 1.686958909034729, Accuracy : 0.2711864411830902

# %%
LSTM_model = get_model(X_train_)
LSTM_model.summary()


from datetime import datetime  
name = datetime.now().strftime("ser_lstm_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=20,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]


LSTM_history = LSTM_model.fit(X_train_, y_train_, 
                       validation_data=(X_val_,y_val_), 
                       batch_size=32,
                       epochs=1000,
                       verbose=1,
                       callbacks=callbacks)


print(f"Loss : {LSTM_model.evaluate(X_test_,y_test_)[0]}, Accuracy : {LSTM_model.evaluate(X_test_,y_test_)[1]}")
# Out:
# Model: "functional_31"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 4096, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,919 (277.03 KB)
#  Trainable params: 70,919 (277.03 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1555 - loss: 1.9471 - val_accuracy: 0.1226 - val_loss: 1.9549
# Epoch 2/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1704 - loss: 1.9410 - val_accuracy: 0.1132 - val_loss: 1.9488
# Epoch 3/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1875 - loss: 1.9412 - val_accuracy: 0.1321 - val_loss: 1.9456
# Epoch 4/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1806 - loss: 1.9379 - val_accuracy: 0.1038 - val_loss: 1.9393
# Epoch 5/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2036 - loss: 1.9309 - val_accuracy: 0.1321 - val_loss: 1.9336
# Epoch 6/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1958 - loss: 1.9277 - val_accuracy: 0.1226 - val_loss: 1.9385
# Epoch 7/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1604 - loss: 1.9330 - val_accuracy: 0.1792 - val_loss: 1.9319
# Epoch 8/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1760 - loss: 1.9269 - val_accuracy: 0.2170 - val_loss: 1.9337
# Epoch 9/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1770 - loss: 1.9269 - val_accuracy: 0.1604 - val_loss: 1.9256
# Epoch 10/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2235 - loss: 1.9122 - val_accuracy: 0.1604 - val_loss: 1.9225
# Epoch 11/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1995 - loss: 1.9081 - val_accuracy: 0.1226 - val_loss: 1.9297
# Epoch 12/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1905 - loss: 1.9024 - val_accuracy: 0.1509 - val_loss: 1.9129
# Epoch 13/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.