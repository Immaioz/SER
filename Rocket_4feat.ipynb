# %%
import os
import re
import sys
import librosa
from random import shuffle
import numpy as np
from typing import Tuple, Union
import pickle
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import joblib
import keras

from tqdm import tqdm

# %%
data_df = pd.read_csv("EMOVO_dataset/data.csv")

# %%
def get_max_min(files):
    min_, max_ = 100, 0
    for file in files:
        sound_file, samplerate = librosa.load(file)
        t = sound_file.shape[0] / samplerate
        if t < min_:
            min_ = t
        if t > max_:
            max_ = t

    return max_, min_

# %%
def extract_new(file,pad):
    X, sample_rate = librosa.load(file)
    max_ = X.shape[0] / sample_rate
    if max_ < pad:
        length = (pad * sample_rate) - X.shape[0]
        X = np.pad(X, (0, int(length)), 'constant')
    
    stft = np.abs(librosa.stft(X))
    # result = np.array([])
    result = []

    # mfccs = np.mean(.T, axis=0)

    mfccs = librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=50)

    # result = np.hstack((result, mfccs))
    result.append((mfccs))

    # chroma = np.mean(.T, axis=0)
    chroma = librosa.feature.chroma_stft(S=stft, sr=sample_rate)
    # result = np.hstack((result, chroma))
    result.append(chroma)

    # mel = np.mean(.T, axis=0) 
    mel = librosa.feature.melspectrogram(y=X, sr=sample_rate)
    # result = np.hstack((result, mel))
    result.append(mel)
    
    # contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T, axis=0)
    contrast = librosa.feature.spectral_contrast(S=stft, sr=sample_rate)
    # result = np.hstack((result, contrast))
    result.append(contrast)

    # tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)
    # result = np.hstack((result, tonnetz))
    return result

# %%
max, min = get_max_min('EMOVO_dataset/'+data_df.file_name)
u = extract_new('EMOVO_dataset/'+data_df.file_name[0], max)

# %%
train_data = pd.DataFrame(columns=['filename', 'features', 'label'])

features = []
for index, file in zip(data_df.index, data_df.file_name):
    train_data.loc[index] = [file, extract_new('EMOVO_dataset/'+file, max), data_df.label[index]]

# %%
output_length = int(np.ceil(max * (22050) / (512)))

X1 = np.empty((0, output_length))
X2 = np.empty((0, output_length))
X3 = np.empty((0, output_length))
X4 = np.empty((0, output_length))

for data in tqdm(train_data["features"]):
    X1 = np.vstack((X1, data[0]))
    X2 = np.vstack((X2, data[1]))
    X3 = np.vstack((X3, data[2]))
    X4 = np.vstack((X4, data[3]))

X1 = X1.reshape(len(data_df),output_length,-1)
X2 = X2.reshape(len(data_df),output_length,-1)
X3 = X3.reshape(len(data_df),output_length,-1)
X4 = X4.reshape(len(data_df),output_length,-1)

# %%
data_classes = (list((train_data["label"].unique())))
Y = keras.utils.to_categorical(list((train_data["label"].apply(data_classes.index))))
# X = np.stack(train_data["features"])
X = np.expand_dims(np.concatenate([X1,X2,X3,X4], axis=2),3)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=22)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=22)

# %%
import keras
model = keras.Sequential()
kernel_sizes = [5, 5]
model.add(keras.layers.Input(shape=(X_train.shape[1],1)))
for size in kernel_sizes:
    model.add(keras.layers.Conv1D(
        filters = 32,
        kernel_size = size,
        padding = 'same'
    ))  # 卷积层
    model.add(keras.layers.BatchNormalization(axis=-1))
    model.add(keras.layers.Activation('relu'))
    model.add(keras.layers.Dropout(0.5))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(32))
model.add(keras.layers.BatchNormalization(axis = -1))
model.add(keras.layers.Activation('relu'))
model.add(keras.layers.Dropout(0.5))

model.add(keras.layers.Dense(7, activation='softmax'))  # 分类层
optimzer = keras.optimizers.Adam(learning_rate= 0.001)
model.compile(loss='categorical_crossentropy', optimizer=opt
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6940 - loss: 0.8438 - val_accuracy: 0.7453 - val_loss: 0.9225
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7001 - loss: 0.8572 - val_accuracy: 0.7264 - val_loss: 0.9123
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6721 - loss: 0.9043 - val_accuracy: 0.7170 - val_loss: 0.9001
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7177 - loss: 0.8126 - val_accuracy: 0.7170 - val_loss: 0.8884
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6781 - loss: 0.8887 - val_accuracy: 0.7264 - val_loss: 0.8785
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.6857 - loss: 0.8913 - val_accuracy: 0.7264 - val_loss: 0.8720
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6729 - loss: 0.8493 - val_accuracy: 0.7358 - val_loss: 0.8687
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.6943 - loss: 0.8446 - val_accuracy: 0.7547 - val_loss: 0.8697
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7328 - loss: 0.7936 - val_accuracy: 0.7453 - val_loss: 0.8722
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7040 - loss: 0.8321 - val_accuracy: 0.7453 - val_loss: 0.8744
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7134 - loss: 0.8373 - val_accuracy: 0.7453 - val_loss: 0.8760
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7232 - loss: 0.8192 - val_accuracy: 0.7358 - val_loss: 0.8755
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7433 - loss: 0.7995 - val_accuracy: 0.7358 - val_loss: 0.8734
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7221 - loss: 0.8036 - val_accuracy: 0.7358 - val_loss: 0.8705
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7325 - loss: 0.7624 - val_accuracy: 0.7358 - val_loss: 0.8697
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7155 - loss: 0.8185 - val_accuracy: 0.7358 - val_loss: 0.8692
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7156 - loss: 0.8203 - val_accuracy: 0.7453 - val_loss: 0.8701
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7140 - loss: 0.7886 - val_accuracy: 0.7453 - val_loss: 0.8724
# Epoch 170/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.7525 - loss: 0.7575 - val_accuracy: 0.7547 - val_loss: 0.8759
# Epoch 171/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.7297 - loss: 0.7903 - val_accuracy: 0.7453 - val_loss: 0.8826
# Epoch 172/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7135 - loss: 0.7715 - val_accuracy: 0.7358 - val_loss: 0.8879
# Epoch 173/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.6836 - loss: 0.8366 - val_accuracy: 0.7358 - val_loss: 0.8917
# Epoch 174/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7347 - loss: 0.7550 - val_accuracy: 0.7264 - val_loss: 0.8960
# Epoch 175/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7070 - loss: 0.8147 - val_accuracy: 0.7358 - val_loss: 0.8965
# Epoch 176/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7611 - loss: 0.7565 - val_accuracy: 0.7358 - val_loss: 0.8974
# Epoch 177/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7219 - loss: 0.7819 - val_accuracy: 0.7170 - val_loss: 0.8959
# Epoch 178/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7535 - loss: 0.7248 - val_accuracy: 0.7170 - val_loss: 0.8935
# Epoch 178: early stopping
# Restoring model weights from the end of the best epoch: 158.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6820 - loss: 0.8699
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6820 - loss: 0.8699
# Loss : 0.8386983275413513, Accuracy : 0.694915235042572

# %%
def obtain_df(X):
    X_df = pd.DataFrame(columns=['filename', 'features', 'label'])

    for index, file in zip(data_df.index, data_df.file_name):
        X_df.loc[index] = [file, pd.Series(X[index]), data_df.label[index]]
    X = pd.DataFrame(X_df["features"])
    return X

from sktime.transformations.panel.rocket import Rocket

def get_rocket(X):
    trf = Rocket(num_kernels=512) 
    trf.fit(X) 
    X_ = trf.transform(X)
    return X_

# %%
X1_ = get_rocket(obtain_df(X1)).to_numpy()
X2_ = get_rocket(obtain_df(X2)).to_numpy()
X3_ = get_rocket(obtain_df(X3)).to_numpy()
X4_ = get_rocket(obtain_df(X4)).to_numpy()

# %%
import tensorflow as tf
from keras.utils import to_categorical

data_classes = (list((train_data["label"].unique())))
Y = to_categorical(list((train_data["label"].apply(data_classes.index))))
# X = np.stack(train_data["features"])
X_ = np.hstack([X1_,X2_,X3_,X4_])

X_train_, X_test_, y_train_, y_test_ = train_test_split(X_, Y, test_size=0.1, random_state=22)
X_train_, X_val_, y_train_, y_val_ = train_test_split(X_train_, y_train_, test_size=0.2, random_state=22)

# %%
import keras
model = keras.Sequential()
kernel_sizes = [5, 5]
model.add(keras.layers.Input(shape=(X_train_.shape[1],1)))
for size in kernel_sizes:
    model.add(keras.layers.Conv1D(
        filters = 32,
        kernel_size = size,
        padding = 'same'
    ))  # 卷积层
    model.add(keras.layers.BatchNormalization(axis=-1))
    model.add(keras.layers.Activation('relu'))
    model.add(keras.layers.Dropout(0.5))

model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(32))
model.add(keras.layers.BatchNormalization(axis = -1))
model.add(keras.layers.Activation('relu'))
model.add(keras.layers.Dropout(0.5))

model.add(keras.layers.Dense(7, activation='softmax')) 
optimzer = keras.optimizers.Adam(learning_rate= 0.001)
model.compile(loss='categorical_crossentropy', optimizer=optimzer, metrics=['accuracy'])

# %%
from datetime import datetime  
name = datetime.now().strftime("ser_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=40,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]



history = model.fit(X_train_, y_train_, 
                       validation_data=(X_val_,y_val_), 
                       batch_size=256,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test_,y_test_)[0]}, Accuracy : {model.evaluate(X_test_,y_test_)[1]}")
# Out:
# Epoch 1/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 439ms/step - accuracy: 0.1339 - loss: 2.5274 - val_accuracy: 0.1792 - val_loss: 8.9938
# Epoch 2/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step - accuracy: 0.2483 - loss: 2.0211 - val_accuracy: 0.1792 - val_loss: 15.2443
# Epoch 3/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - accuracy: 0.2677 - loss: 1.9988 - val_accuracy: 0.1792 - val_loss: 15.7616
# Epoch 4/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 0.3321 - loss: 1.7911 - val_accuracy: 0.1792 - val_loss: 13.8166
# Epoch 5/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - accuracy: 0.3609 - loss: 1.7095 - val_accuracy: 0.1887 - val_loss: 11.2275
# Epoch 6/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - accuracy: 0.3316 - loss: 1.7135 - val_accuracy: 0.1887 - val_loss: 9.3695
# Epoch 7/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 323ms/step - accuracy: 0.3694 - loss: 1.6280 - val_accuracy: 0.1981 - val_loss: 8.1566
# Epoch 8/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 0.3931 - loss: 1.5662 - val_accuracy: 0.1887 - val_loss: 7.1853
# Epoch 9/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.3531 - loss: 1.5800 - val_accuracy: 0.2075 - val_loss: 6.5973
# Epoch 10/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 315ms/step - accuracy: 0.3800 - loss: 1.5749 - val_accuracy: 0.2170 - val_loss: 6.0411
# Epoch 11/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 316ms/step - accuracy: 0.4169 - loss: 1.5142 - val_accuracy: 0.2075 - val_loss: 5.6396
# Epoch 12/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - accuracy: 0.4379 - loss: 1.4500 - val_accuracy: 0.2075 - val_loss: 5.3376
# Epoch 13/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 0.4261 - loss: 1.4606 - val_accuracy: 0.1981 - val_loss: 5.0155
# Epoch 14/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 0.4191 - loss: 1.4989 - val_accuracy: 0.1887 - val_loss: 4.8700
# Epoch 15/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step - accuracy: 0.4848 - loss: 1.4007 - val_accuracy: 0.2075 - val_loss: 4.7788
# Epoch 16/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step - accuracy: 0.4612 - loss: 1.4321 - val_accuracy: 0.2075 - val_loss: 4.5974
# Epoch 17/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s
# Epoch 144/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 313ms/step - accuracy: 0.8290 - loss: 0.5245 - val_accuracy: 0.5472 - val_loss: 1.1801
# Epoch 145/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.8360 - loss: 0.4746 - val_accuracy: 0.5377 - val_loss: 1.1778
# Epoch 146/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.8518 - loss: 0.4755 - val_accuracy: 0.5377 - val_loss: 1.1817
# Epoch 147/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - accuracy: 0.8803 - loss: 0.4764 - val_accuracy: 0.5377 - val_loss: 1.1848
# Epoch 148/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step - accuracy: 0.8125 - loss: 0.5257 - val_accuracy: 0.5566 - val_loss: 1.1743
# Epoch 149/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 316ms/step - accuracy: 0.8520 - loss: 0.4788 - val_accuracy: 0.5472 - val_loss: 1.1747
# Epoch 150/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - accuracy: 0.8484 - loss: 0.4667 - val_accuracy: 0.5189 - val_loss: 1.1827
# Epoch 151/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step - accuracy: 0.8614 - loss: 0.4641 - val_accuracy: 0.5189 - val_loss: 1.1920
# Epoch 152/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 331ms/step - accuracy: 0.8295 - loss: 0.4834 - val_accuracy: 0.5094 - val_loss: 1.1945
# Epoch 153/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 325ms/step - accuracy: 0.8397 - loss: 0.4541 - val_accuracy: 0.5094 - val_loss: 1.1982
# Epoch 154/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 317ms/step - accuracy: 0.8078 - loss: 0.5165 - val_accuracy: 0.5094 - val_loss: 1.2004
# Epoch 155/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step - accuracy: 0.8968 - loss: 0.3802 - val_accuracy: 0.5283 - val_loss: 1.2025
# Epoch 156/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - accuracy: 0.8717 - loss: 0.4266 - val_accuracy: 0.5283 - val_loss: 1.2061
# Epoch 157/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 346ms/step - accuracy: 0.8489 - loss: 0.4277 - val_accuracy: 0.5094 - val_loss: 1.2088
# Epoch 158/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 338ms/step - accuracy: 0.8463 - loss: 0.4798 - val_accuracy: 0.5000 - val_loss: 1.2187
# Epoch 159/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 314ms/step - accuracy: 0.8554 - loss: 0.4481 - val_accuracy: 0.5000 - val_loss: 1.2323
# Epoch 160/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 0.8863 - loss: 0.3786 - val_accuracy: 0.5094 - val_loss: 1.2547
# Epoch 161/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 348ms/step - accuracy: 0.8860 - loss: 0.3863 - val_accuracy: 0.5094 - val_loss: 1.2771
# Epoch 162/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - accuracy: 0.8431 - loss: 0.4709 - val_accuracy: 0.5094 - val_loss: 1.2949
# Epoch 163/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step - accuracy: 0.8638 - loss: 0.4164 - val_accuracy: 0.5094 - val_loss: 1.3117
# Epoch 164/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - accuracy: 0.8666 - loss: 0.4068 - val_accuracy: 0.5189 - val_loss: 1.3361
# Epoch 165/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 337ms/step - accuracy: 0.8340 - loss: 0.4491 - val_accuracy: 0.5000 - val_loss: 1.3430
# Epoch 166/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 0.8559 - loss: 0.4192 - val_accuracy: 0.5094 - val_loss: 1.3223
# Epoch 167/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step - accuracy: 0.8991 - loss: 0.3619 - val_accuracy: 0.5000 - val_loss: 1.2870
# Epoch 168/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 364ms/step - accuracy: 0.8538 - loss: 0.4212 - val_accuracy: 0.5094 - val_loss: 1.2587
# Epoch 169/1000
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step - accuracy: 0.8709 - loss: 0.3999 - val_accuracy: 0.5094 - val_loss: 1.2315
# Epoch 169: early stopping
# Restoring model weights from the end of the best epoch: 129.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4735 - loss: 1.6095
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4735 - loss: 1.6095
# Loss : 1.5302621126174927, Accuracy : 0.49152541160583496

# %% [markdown]
# # LSTM

# %%
from keras import layers, models
def get_model(X_train):
    inputs = layers.Input(shape=(X_train.shape[1],1))
    encoder = layers.LSTM(128)(inputs)
    drop = layers.Dropout(0.3)(encoder)
    hidden = layers.Dense(32, activation='relu')(drop)
    outputs = layers.Dense(7, activation='softmax')(hidden)
    
    model = models.Model(inputs, outputs)
    optimizer = keras.optimizers.Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=["accuracy"])

    return model

# %%
LSTM_model = get_model(X_train)
LSTM_model.summary()


from datetime import datetime  
name = datetime.now().strftime("ser_lstm_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=20,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]


LSTM_history = LSTM_model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       verbose=1,
                       callbacks=callbacks)


print(f"Loss : {LSTM_model.evaluate(X_test,y_test)[0]}, Accuracy : {LSTM_model.evaluate(X_test,y_test)[1]}")
# Out:
# Model: "functional_30"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_4 (InputLayer)      │ (None, 197, 1)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,919 (277.03 KB)
#  Trainable params: 70,919 (277.03 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step - accuracy: 0.1444 - loss: 2.0246 - val_accuracy: 0.1226 - val_loss: 1.9662
# Epoch 2/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1358 - loss: 1.9650 - val_accuracy: 0.1132 - val_loss: 1.9588
# Epoch 3/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1250 - loss: 1.9794 - val_accuracy: 0.0755 - val_loss: 1.9632
# Epoch 4/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.1612 - loss: 1.9545 - val_accuracy: 0.0755 - val_loss: 1.9591
# Epoch 5/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1323 - loss: 1.9667 - val_accuracy: 0.1132 - val_loss: 1.9597
# Epoch 6/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.1600 - loss: 1.9467 - val_accuracy: 0.1132 - val_loss: 1.9565
# Epoch 7/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.1384 - loss: 1.9565 - val_accuracy: 0.1132 - val_loss: 1.9457
# Epoch 8/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1179 - loss: 1.9656 - val_accuracy: 0.2075 - val_loss: 1.9394
# Epoch 9/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1354 - loss: 1.9533 - val_accuracy: 0.1981 - val_loss: 1.9413
# Epoch 10/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.0976 - loss: 1.9529 - val_accuracy: 0.1792 - val_loss: 1.9365
# Epoch 11/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1708 - loss: 1.9347 - val_accuracy: 0.1132 - val_loss: 1.9431
# Epoch 12/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1985 - loss: 1.9407 - val_accuracy: 0.2547 - val_loss: 1.9386
# Epoch 13/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1407 - loss: 1.9531 - val_accuracy: 0.2453 - val_loss: 1.9354
# Epoch 14/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.1801 - loss: 1.9452 - val_accuracy: 0.2170 - val_loss: 1.9425
# Epoch 15/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1715 - loss: 1.9403 - val_accuracy: 0.1132 - val_loss: 1.9369
# Epoch 16/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1908 - loss: 1.9246 - val_accuracy: 0.2453 - val_loss: 1.9184
# Epoch 17/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2050 - loss: 1.9299 - val_accuracy: 0.2075 - val_loss: 1.8976
# Epoch 18/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2403 - loss: 1.9029 - val_accuracy: 0.1981 - val_loss: 1.9190
# Epoch 19/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - accuracy: 0.2199 - loss: 1.9140 - val_accuracy: 0.1698 - val_loss: 1.9301
# Epoch 20/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1744 - loss: 1.9356 - val_accuracy: 0.2736 - val_loss: 1.8976
# Epoch 21/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2061 - loss: 1.8986 - val_accuracy: 0.3019 - val_loss: 1.8549
# Epoch 22/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2433 - loss: 1.8718 - val_accuracy: 0.2642 - val_loss: 1.8036
# Epoch 23/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.1889 - loss: 1.8811 - val_accuracy: 0.3208 - val_loss: 1.7960
# Epoch 24/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2215 - loss: 1.8665 - val_accuracy: 0.2642 - val_loss: 1.7973
# Epoch 25/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2132 - loss: 1.8784 - val_accuracy: 0.2075 - val_loss: 1.8817
# Epoch 26/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - accuracy: 0.2275 - loss: 1.8649 - val_accuracy: 0.3302 - val_loss: 1.7722
# Epoch 27/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.2167 - loss: 1.8812 - val_accuracy: 0.2264 - val_loss: 1.8475
# Epoch 28/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.
1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2837 - loss: 1.6832 - val_accuracy: 0.3491 - val_loss: 1.6598
# Epoch 126/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3440 - loss: 1.6728 - val_accuracy: 0.3679 - val_loss: 1.6611
# Epoch 127/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2953 - loss: 1.6937 - val_accuracy: 0.3679 - val_loss: 1.6684
# Epoch 128/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3546 - loss: 1.6537 - val_accuracy: 0.2736 - val_loss: 1.7115
# Epoch 129/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.2971 - loss: 1.7060 - val_accuracy: 0.3396 - val_loss: 1.6523
# Epoch 130/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3466 - loss: 1.6510 - val_accuracy: 0.3396 - val_loss: 1.6615
# Epoch 131/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3447 - loss: 1.6990 - val_accuracy: 0.3113 - val_loss: 1.7125
# Epoch 132/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3181 - loss: 1.7184 - val_accuracy: 0.3585 - val_loss: 1.6541
# Epoch 133/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3135 - loss: 1.7045 - val_accuracy: 0.3679 - val_loss: 1.6593
# Epoch 134/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3300 - loss: 1.6748 - val_accuracy: 0.3396 - val_loss: 1.6924
# Epoch 135/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3016 - loss: 1.6665 - val_accuracy: 0.3585 - val_loss: 1.6553
# Epoch 136/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.3452 - loss: 1.6810 - val_accuracy: 0.3208 - val_loss: 1.6520
# Epoch 137/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.3579 - loss: 1.6743 - val_accuracy: 0.3679 - val_loss: 1.6516
# Epoch 137: early stopping
# Restoring model weights from the end of the best epoch: 117.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2641 - loss: 1.6817
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.2641 - loss: 1.6817
# Loss : 1.686958909034729, Accuracy : 0.2711864411830902

# %%
LSTM_model = get_model(X_train_)
LSTM_model.summary()


from datetime import datetime  
name = datetime.now().strftime("ser_lstm_%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=20,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]


LSTM_history = LSTM_model.fit(X_train_, y_train_, 
                       validation_data=(X_val_,y_val_), 
                       batch_size=32,
                       epochs=1000,
                       verbose=1,
                       callbacks=callbacks)


print(f"Loss : {LSTM_model.evaluate(X_test_,y_test_)[0]}, Accuracy : {LSTM_model.evaluate(X_test_,y_test_)[1]}")
# Out:
# Model: "functional_31"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)      │ (None, 4096, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 128)            │        66,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 32)             │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 7)              │           231 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,919 (277.03 KB)
#  Trainable params: 70,919 (277.03 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.1555 - loss: 1.9471 - val_accuracy: 0.1226 - val_loss: 1.9549
# Epoch 2/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1704 - loss: 1.9410 - val_accuracy: 0.1132 - val_loss: 1.9488
# Epoch 3/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1875 - loss: 1.9412 - val_accuracy: 0.1321 - val_loss: 1.9456
# Epoch 4/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1806 - loss: 1.9379 - val_accuracy: 0.1038 - val_loss: 1.9393
# Epoch 5/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2036 - loss: 1.9309 - val_accuracy: 0.1321 - val_loss: 1.9336
# Epoch 6/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1958 - loss: 1.9277 - val_accuracy: 0.1226 - val_loss: 1.9385
# Epoch 7/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1604 - loss: 1.9330 - val_accuracy: 0.1792 - val_loss: 1.9319
# Epoch 8/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1760 - loss: 1.9269 - val_accuracy: 0.2170 - val_loss: 1.9337
# Epoch 9/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1770 - loss: 1.9269 - val_accuracy: 0.1604 - val_loss: 1.9256
# Epoch 10/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2235 - loss: 1.9122 - val_accuracy: 0.1604 - val_loss: 1.9225
# Epoch 11/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1995 - loss: 1.9081 - val_accuracy: 0.1226 - val_loss: 1.9297
# Epoch 12/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1905 - loss: 1.9024 - val_accuracy: 0.1509 - val_loss: 1.9129
# Epoch 13/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1655 - loss: 1.9105 - val_accuracy: 0.2264 - val_loss: 1.9219
# Epoch 14/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2120 - loss: 1.9179 - val_accuracy: 0.1604 - val_loss: 1.9061
# Epoch 15/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2073 - loss: 1.8979 - val_accuracy: 0.2170 - val_loss: 1.9114
# Epoch 16/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1858 - loss: 1.9022 - val_accuracy: 0.1981 - val_loss: 1.9090
# Epoch 17/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2179 - loss: 1.8965 - val_accuracy: 0.1792 - val_loss: 1.9114
# Epoch 18/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2026 - loss: 1.9086 - val_accuracy: 0.2358 - val_loss: 1.9033
# Epoch 19/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2045 - loss: 1.9055 - val_accuracy: 0.2642 - val_loss: 1.9132
# Epoch 20/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2411 - loss: 1.8918 - val_accuracy: 0.1698 - val_loss: 1.9123
# Epoch 21/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1912 - loss: 1.8985 - val_accuracy: 0.2642 - val_loss: 1.9097
# Epoch 22/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.2161 - loss: 1.8988 - val_accuracy: 0.2642 - val_loss: 1.9048
# Epoch 23/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.2098 - loss: 1.8694 - val_accuracy: 0.2642 - val_loss: 1.9015
# Epoch 24/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2019 - loss: 1.8897 - val_accuracy: 0.2358 - val_loss: 1.9042
# Epoch 25/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2137 - loss: 1.8865 - val_accuracy: 0.2170 - val_loss: 1.8985
# Epoch 26/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2042 - loss: 1.8768 - val_accuracy: 0.2547 - val_loss: 1.8953
# Epoch 27/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2058 - loss: 1.8979 - val_accuracy: 0.2642 - val_loss: 1.8961
# Epoch 28/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.1979 - loss: 1.8949 - val_accuracy: 0.2736 - val_loss: 1.9088
# Epoch 29/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2091 - loss: 1.8898 - val_accuracy: 0.2736 - val_loss: 1.8941
# Epoch 30/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2264 - loss: 1.8603 - val_accuracy: 0.2642 - val_loss: 1.8984
# Epoch 31/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.2581 - loss: 1.8744 - val_accuracy: 0.2925 - val_loss: 1.8920
# Epoch 32/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.2186 - loss: 1.8921 - val_accuracy: 0.2830 - val_loss: 1.8896
# Epoch 33/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2212 - loss: 1.8953 - val_accuracy: 0.2736 - val_loss: 1.8887
# Epoch 34/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 1s/step - accuracy: 0.2320 - loss: 1.8665 - val_accuracy: 0.2830 - val_loss: 1.8894
# Epoch 35/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2388 - loss: 1.8672 - val_accuracy: 0.2830 - val_loss: 1.8862
# Epoch 36/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.2232 - loss: 1.8885 - val_accuracy: 0.2925 - val_loss: 1.8958
# Epoch 37/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.1907 - loss: 1.9065 - val_accuracy: 0.2736 - val_loss: 1.8862
# Epoch 38/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.2483 - loss: 1.8490 - val_accuracy: 0.2830 - val_loss: 1.8810
# Epoch 39/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2405 - loss: 1.8945 - val_accuracy: 0.2736 - val_loss: 1.8766
# Epoch 40/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2261 - loss: 1.8918 - val_accuracy: 0.2642 - val_loss: 1.8815
# Epoch 41/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.2340 - loss: 1.8667 - val_accuracy: 0.2736 - val_loss: 1.8785
# Epoch 42/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.2709 - loss: 1.8711 - val_accuracy: 0.2642 - val_loss: 1.8843
# Epoch 43/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 18s 1s/step - accuracy: 0.2580 - loss: 1.8783 - val_accuracy: 0.2642 - val_loss: 1.8754
# Epoch 44/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 17s 1s/step - accuracy: 0.2723 - loss: 1.8485 - val_accuracy: 0.2453 - val_loss: 1.8763
# Epoch 45/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 15s 1s/step - accuracy: 0.