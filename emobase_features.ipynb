# %%
import pandas as pd
import opensmile
from tqdm import tqdm
import keras
import numpy as np
from sklearn.model_selection import train_test_split
import librosa

# %%
def return_features(file,pad):
    X, sample_rate = librosa.load(file)
    max_ = X.shape[0] / sample_rate
    if max_ < pad:
        length = (pad * sample_rate) -  (X.shape[0] / sample_rate)
        X = librosa.util.pad_center(X, size = length, mode = 'constant')
    smile = opensmile.Smile(
    feature_set=opensmile.FeatureSet.emobase,
    feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
    )
    y = smile.process_signal(X,sample_rate)
    #  smile.process_file(file, end=3)
    return y
def get_max_min(files):
    min_, max_ = 100, 0
    for file in files:
        sound_file, samplerate = librosa.load(file)
        t = sound_file.shape[0] / samplerate
        if t < min_:
            min_ = t
        if t >= max_:
            max_ = t

    return np.round(max_,2) + 0.01, min_

# %%
data_df = pd.read_csv("EMOVO_dataset/data.csv")

# %%
train_data = pd.DataFrame(columns=['filename', 'features', 'label'])
max, min = get_max_min('EMOVO_dataset/'+data_df.file_name)
features = []
for index, file in tqdm(zip(data_df.index, data_df.file_name)):
    train_data.loc[index] = [file, return_features('EMOVO_dataset/'+file,max), data_df.label[index]]
# Out:
# 588it [01:02,  9.38it/s]

# %%
data_classes = (list((train_data["label"].unique())))
Y = keras.utils.to_categorical(list((train_data["label"].apply(data_classes.index))))
# X = np.concatenate([X1,X2,X3,X4], axis=2)
X = np.expand_dims(np.stack(train_data["features"]),3)


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=22)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=22)

# %%
def get_cnn(input_shape):
    model = keras.Sequential()

    model.add(keras.layers.Input(shape=input_shape))

    model.add(keras.layers.Conv2D(256, 3, activation='relu' ))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))

    model.add(keras.layers.Conv2D(128, 3, activation='relu'))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))


    model.add(keras.layers.Conv2D(64, 3, activation='relu'))
    model.add(keras.layers.MaxPooling2D(padding='same'))
    model.add(keras.layers.Dropout(rate=0.3))

    model.add(keras.layers.GlobalAveragePooling2D())
    model.add(keras.layers.Dense(1024, activation='relu'))
    
    model.add(keras.layers.Dense(256, activation='relu'))
    model.add(keras.layers.Dense(64, activation='relu'))

    model.add(keras.layers.Dense(7, activation='softmax'))

    optimzer = keras.optimizers.Adam()
    model.compile(loss='categorical_crossentropy', optimizer=optimzer, metrics=['accuracy'])

    return model

# %%
from datetime import datetime  
name = datetime.now().strftime("model/emobase_feat/SER_EMOVO_Clean%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=10,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

model = get_cnn((X_train.shape[1:]))
# model.summary()

# %%
history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1581 - loss: 2.0543
# Epoch 1: val_loss improved from inf to 1.93774, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.1557 - loss: 2.0524 - val_accuracy: 0.1792 - val_loss: 1.9377
# Epoch 2/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1472 - loss: 1.9449
# Epoch 2: val_loss did not improve from 1.93774
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.1467 - loss: 1.9452 - val_accuracy: 0.1792 - val_loss: 1.9451
# Epoch 3/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1339 - loss: 1.9431
# Epoch 3: val_loss did not improve from 1.93774
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.1338 - loss: 1.9431 - val_accuracy: 0.0943 - val_loss: 1.9446
# Epoch 4/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1775 - loss: 1.9393
# Epoch 4: val_loss did not improve from 1.93774
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.1778 - loss: 1.9392 - val_accuracy: 0.1321 - val_loss: 1.9446
# Epoch 5/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.1612 - loss: 1.9256
# Epoch 5: val_loss improved from 1.93774 to 1.89810, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.1612 - loss: 1.9262 - val_accuracy: 0.2736 - val_loss: 1.8981
# Epoch 6/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2221 - loss: 1.9064
# Epoch 6: val_loss did not improve from 1.89810
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.2212 - loss: 1.9070 - val_accuracy: 0.1887 - val_loss: 1.9136
# Epoch 7/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1537 - loss: 1.9535
# Epoch 7: val_loss did not improve from 1.89810
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.1545 - loss: 1.9525 - val_accuracy: 0.2170 - val_loss: 1.9196
# Epoch 8/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2137 - loss: 1.8949
# Epoch 8: val_loss improved from 1.89810 to 1.85788, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.2140 - loss: 1.8946 - val_accuracy: 0.2358 - val_loss: 1.8579
# Epoch 9/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2140 - loss: 1.8641
# Epoch 9: val_loss improved from 1.85788 to 1.81899, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.2155 - loss: 1.8635 - val_accuracy: 0.2453 - val_loss: 1.8190
# Epoch 10/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1987 - loss: 1.8798
# Epoch 10: val_loss improved from 1.81899 to 1.78930, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 19s 1s/step - accuracy: 0.2003 - loss: 1.8783 - val_accuracy: 0.3396 - val_loss: 1.7893
# Epoch 11/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2887 - loss: 1.7916
# Epoch 11: val_loss did not improve from 1.78930
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.2883 - loss: 1.7907 - val_accuracy: 0.2547 - val_loss: 1.8906
# Epoch 12/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2197 - loss: 1.8454
# Epoch 12: val_loss did not improve from 1.78930
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.2214 - loss: 1.8450 - val_accuracy: 0.3208 - val_loss: 1.8120
# Epoch 13/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3208 - loss: 1.7364
# Epoch 13: val_loss did not improve from 1.78930
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.3212 - loss: 1.7352 - val_accuracy: 0.2170 - val_loss: 1.9055
# Epoch 14/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2674 - loss: 1.8021
# Epoch 14: val_loss improved from 1.78930 to 1.65674, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.2694 - loss: 1.7980 - val_accuracy: 0.3113 - val_loss: 1.6567
# Epoch 15/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3403 - loss: 1.6408
# Epoch 15: val_loss did not improve from 1.65674
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.3419 - loss: 1.6405 - val_accuracy: 0.3868 - val_loss: 1.6610
# Epoch 16/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3606 - loss: 1.5581
# Epoch 16: val_loss improved from 1.65674 to 1.57202, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.3580 - loss: 1.5615 - val_accuracy: 0.4434 - val_loss: 1.5720
# Epoch 17/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3737 - loss: 1.5703
# Epoch 17: val_loss did not improve from 1.57202
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.3705 - loss: 1.5741 - val_accuracy: 0.3679 - val_loss: 1.6279
# Epoch 18/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3619 - loss: 1.5618
# Epoch 18: val_loss did not improve from 1.57202
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.3617 - loss: 1.5630 - val_accuracy: 0.3302 - val_loss: 1.6301
# Epoch 19/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3757 - loss: 1.5779
# Epoch 19: val_loss improved from 1.57202 to 1.54980, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 2s/step - accuracy: 0.3751 - loss: 1.5767 - val_accuracy: 0.3962 - val_loss: 1.5498
# Epoch 20/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4291 - loss: 1.4893
# Epoch 20: val_loss improved from 1.54980 to 1.53971, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4281 - loss: 1.4885 - val_accuracy: 0.3585 - val_loss: 1.5397
# Epoch 21/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4567 - loss: 1.4307
# Epoch 21: val_loss improved from 1.53971 to 1.47266, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4556 - loss: 1.4316 - val_accuracy: 0.4151 - val_loss: 1.4727
# Epoch 22/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3984 - loss: 1.5062
# Epoch 22: val_loss improved from 1.47266 to 1.40540, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.3997 - loss: 1.5037 - val_accuracy: 0.4245 - val_loss: 1.4054
# Epoch 23/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4815 - loss: 1.2948
# Epoch 23: val_loss improved from 1.40540 to 1.37128, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4798 - loss: 1.2981 - val_accuracy: 0.4528 - val_loss: 1.3713
# Epoch 24/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4689 - loss: 1.3576
# Epoch 24: val_loss improved from 1.37128 to 1.34477, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4665 - loss: 1.3606 - val_accuracy: 0.4717 - val_loss: 1.3448
# Epoch 25/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4346 - loss: 1.3642
# Epoch 25: val_loss improved from 1.34477 to 1.31105, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4360 - loss: 1.3651 - val_accuracy: 0.4717 - val_loss: 1.3111
# Epoch 26/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5164 - loss: 1.2601
# Epoch 26: val_loss did not improve from 1.31105
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5148 - loss: 1.2618 - val_accuracy: 0.4811 - val_loss: 1.4054
# Epoch 27/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4458 - loss: 1.4319
# Epoch 27: val_loss did not improve from 1.31105
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4451 - loss: 1.4318 - val_accuracy: 0.5094 - val_loss: 1.3439
# Epoch 28/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4811 - loss: 1.3214
# Epoch 28: val_loss improved from 1.31105 to 1.28429, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.4814 - loss: 1.3216 - val_accuracy: 0.4906 - val_loss: 1.2843
# Epoch 29/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5388 - loss: 1.2263
# Epoch 29: val_loss did not improve from 1.28429
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5380 - loss: 1.2253 - val_accuracy: 0.4434 - val_loss: 1.3808
# Epoch 30/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5590 - loss: 1.2558
# Epoch 30: val_loss did not improve from 1.28429
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5589 - loss: 1.2551 - val_accuracy: 0.5094 - val_loss: 1.3195
# Epoch 31/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5214 - loss: 1.2134
# Epoch 31: val_loss improved from 1.28429 to 1.25989, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5218 - loss: 1.2110 - val_accuracy: 0.5566 - val_loss: 1.2599
# Epoch 32/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5759 - loss: 1.0938
# Epoch 32: val_loss did not improve from 1.25989
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.5742 - loss: 1.0960 - val_accuracy: 0.5377 - val_loss: 1.3032
# Epoch 33/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6496 - loss: 1.0308
# Epoch 33: val_loss did not improve from 1.25989
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 2s/step - accuracy: 0.6461 - loss: 1.0357 - val_accuracy: 0.5000 - val_loss: 1.3850
# Epoch 34/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6138 - loss: 1.0562
# Epoch 34: val_loss improved from 1.25989 to 1.23669, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 2s/step - accuracy: 0.6139 - loss: 1.0549 - val_accuracy: 0.5377 - val_loss: 1.2367
# Epoch 35/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6232 - loss: 1.0351
# Epoch 35: val_loss did not improve from 1.23669
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.6220 - loss: 1.0352 - val_accuracy: 0.4717 - val_loss: 1.2595
# Epoch 36/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5839 - loss: 1.0799
# Epoch 36: val_loss improved from 1.23669 to 1.14261, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5837 - loss: 1.0789 - val_accuracy: 0.5566 - val_loss: 1.1426
# Epoch 37/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5912 - loss: 1.0231
# Epoch 37: val_loss did not improve from 1.14261
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.5923 - loss: 1.0249 - val_accuracy: 0.5849 - val_loss: 1.1489
# Epoch 38/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6257 - loss: 0.9737
# Epoch 38: val_loss improved from 1.14261 to 1.12179, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6251 - loss: 0.9743 - val_accuracy: 0.6038 - val_loss: 1.1218
# Epoch 39/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6042 - loss: 0.9574
# Epoch 39: val_loss did not improve from 1.12179
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6041 - loss: 0.9579 - val_accuracy: 0.5660 - val_loss: 1.1452
# Epoch 40/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6305 - loss: 0.8912
# Epoch 40: val_loss did not improve from 1.12179
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6307 - loss: 0.8940 - val_accuracy: 0.5283 - val_loss: 1.2093
# Epoch 41/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6347 - loss: 0.9086
# Epoch 41: val_loss did not improve from 1.12179
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6343 - loss: 0.9092 - val_accuracy: 0.5660 - val_loss: 1.2094
# Epoch 42/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6318 - loss: 0.9479
# Epoch 42: val_loss did not improve from 1.12179
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6317 - loss: 0.9477 - val_accuracy: 0.5283 - val_loss: 1.3373
# Epoch 43/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6536 - loss: 0.8849
# Epoch 43: val_loss improved from 1.12179 to 1.09747, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6534 - loss: 0.8847 - val_accuracy: 0.5943 - val_loss: 1.0975
# Epoch 44/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6909 - loss: 0.7945
# Epoch 44: val_loss improved from 1.09747 to 1.01536, saving model to model/emobase_feat/SER_EMOVO_Clean05_10_2024_11_16_59.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6925 - loss: 0.7923 - val_accuracy: 0.6038 - val_loss: 1.0154
# Epoch 45/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6645 - loss: 0.8683
# Epoch 45: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6643 - loss: 0.8705 - val_accuracy: 0.5377 - val_loss: 1.1784
# Epoch 46/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6878 - loss: 0.8339
# Epoch 46: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6874 - loss: 0.8334 - val_accuracy: 0.5283 - val_loss: 1.1340
# Epoch 47/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7212 - loss: 0.7642
# Epoch 47: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7202 - loss: 0.7662 - val_accuracy: 0.5755 - val_loss: 1.1083
# Epoch 48/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7141 - loss: 0.7897
# Epoch 48: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7139 - loss: 0.7889 - val_accuracy: 0.5660 - val_loss: 1.1134
# Epoch 49/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6568 - loss: 0.8290
# Epoch 49: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6597 - loss: 0.8255 - val_accuracy: 0.5943 - val_loss: 1.0330
# Epoch 50/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7370 - loss: 0.7411
# Epoch 50: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7363 - loss: 0.7382 - val_accuracy: 0.5755 - val_loss: 1.0691
# Epoch 51/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7692 - loss: 0.6531
# Epoch 51: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7683 - loss: 0.6540 - val_accuracy: 0.6321 - val_loss: 1.0322
# Epoch 52/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7775 - loss: 0.5781
# Epoch 52: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7764 - loss: 0.5798 - val_accuracy: 0.6321 - val_loss: 1.0610
# Epoch 53/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7506 - loss: 0.6390
# Epoch 53: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.7498 - loss: 0.6419 - val_accuracy: 0.5660 - val_loss: 1.1131
# Epoch 54/1000
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6792 - loss: 0.7349
# Epoch 54: val_loss did not improve from 1.01536
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - accuracy: 0.6812 - loss: 0.7336 - val_accuracy: 0.6132 - val_loss: 1.0306
# Epoch 54: early stopping
# Restoring model weights from the end of the best epoch: 44.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.5708 - loss: 1.1156
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step - accuracy: 0.5708 - loss: 1.1156
# Loss : 1.1051205396652222, Accuracy : 0.5593220591545105

# %%
data_df = pd.read_csv("RAVDESS/data.csv")
data_df.drop(data_df[data_df['label'] == "calm"].index, inplace = True)
data_df = data_df.reset_index()

# %%
train_data = pd.DataFrame(columns=['filename', 'features', 'label'])
max, min = get_max_min('RAVDESS/'+data_df.file_name)
features = []
for index, file in tqdm(zip(data_df.index, data_df.file_name)):
    train_data.loc[index] = [file, return_features('RAVDESS/'+file,max), data_df.label[index]]
# Out:
# 1248it [01:08, 18.09it/s]

# %%
X, sample_rate = librosa.load('RAVDESS/'+data_df.file_name[10])
max_ = X.shape[0] / sample_rate
print(max_)

if max_ <= max:
    length = (max * sample_rate) -  (X.shape[0] / sample_rate)
    print(length)
    X = librosa.util.pad_center(X, size = length, mode = 'constant')
print(np.round(X.shape[0] / sample_rate,2))

smile = opensmile.Smile(
feature_set=opensmile.FeatureSet.emobase,
feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

y = smile.process_signal(X,sample_rate)
X.shape, y.shape
# Out:
# 3.937278911564626
# 116420.06272108843
# 5.28
# ((116420,), (524, 26))

# %%
X, sample_rate = librosa.load('RAVDESS/'+data_df.file_name[1129])
max_ = X.shape[0] / sample_rate
print(max_)
print(max)
if max_ <= max:
    length = (max * sample_rate) -  (X.shape[0] / sample_rate)
    print(length)
    X = librosa.util.pad_center(X, size = length, mode = 'constant')
print(np.round(X.shape[0] / sample_rate,2))

smile = opensmile.Smile(
feature_set=opensmile.FeatureSet.emobase,
feature_level=opensmile.FeatureLevel.LowLevelDescriptors,
)

y = smile.process_signal(X,sample_rate)
X.shape, y.shape
# Out:
# 3.9039002267573695
# 5.279999999999999
# 116420.09609977323
# 5.28
# ((116420,), (524, 26))

# %%
for i,feat in enumerate(train_data["features"]):
    if feat.shape != (524,26):
        print(feat.shape,i)

# %%
data_classes = (list((train_data["label"].unique())))
Y = keras.utils.to_categorical(list((train_data["label"].apply(data_classes.index))))
# X = np.concatenate([X1,X2,X3,X4], axis=2)
X = np.expand_dims(np.stack(train_data["features"]),3)


X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.1, random_state=22)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=22)

# %%
from datetime import datetime  
name = datetime.now().strftime("model/emobase_feat/SER_RAVDESS_Clean%d_%m_%Y_%H_%M_%S.keras")  

callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath = name,
        save_best_only=True,
        verbose=1,
        monitor="val_loss"),

    keras.callbacks.EarlyStopping(  
        monitor="val_loss",
        min_delta=0.001,
        patience=10,
        verbose=1,
        mode="auto",
        restore_best_weights=True
    )
]

model = get_cnn((X_train.shape[1:]))
# model.summary()

# %%
history = model.fit(X_train, y_train, 
                       validation_data=(X_val,y_val), 
                       batch_size=32,
                       epochs=1000,
                       callbacks=callbacks)


print(f"Loss : {model.evaluate(X_test,y_test)[0]}, Accuracy : {model.evaluate(X_test,y_test)[1]}")
# Out:
# Epoch 1/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.1534 - loss: 2.0413
# Epoch 1: val_loss improved from inf to 1.91715, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 446ms/step - accuracy: 0.1540 - loss: 2.0371 - val_accuracy: 0.2089 - val_loss: 1.9171
# Epoch 2/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step - accuracy: 0.1527 - loss: 1.9223
# Epoch 2: val_loss improved from 1.91715 to 1.89592, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 477ms/step - accuracy: 0.1524 - loss: 1.9218 - val_accuracy: 0.1867 - val_loss: 1.8959
# Epoch 3/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 523ms/step - accuracy: 0.2055 - loss: 1.8901
# Epoch 3: val_loss did not improve from 1.89592
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 544ms/step - accuracy: 0.2048 - loss: 1.8908 - val_accuracy: 0.1822 - val_loss: 1.9080
# Epoch 4/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 539ms/step - accuracy: 0.1870 - loss: 1.9065
# Epoch 4: val_loss improved from 1.89592 to 1.88480, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - accuracy: 0.1870 - loss: 1.9059 - val_accuracy: 0.1733 - val_loss: 1.8848
# Epoch 5/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step - accuracy: 0.2247 - loss: 1.8750
# Epoch 5: val_loss improved from 1.88480 to 1.85772, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 492ms/step - accuracy: 0.2257 - loss: 1.8744 - val_accuracy: 0.2356 - val_loss: 1.8577
# Epoch 6/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.2569 - loss: 1.8247
# Epoch 6: val_loss improved from 1.85772 to 1.82851, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 478ms/step - accuracy: 0.2566 - loss: 1.8241 - val_accuracy: 0.2133 - val_loss: 1.8285
# Epoch 7/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.2994 - loss: 1.7695
# Epoch 7: val_loss did not improve from 1.82851
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 478ms/step - accuracy: 0.2995 - loss: 1.7685 - val_accuracy: 0.1956 - val_loss: 1.8978
# Epoch 8/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.2627 - loss: 1.8193
# Epoch 8: val_loss improved from 1.82851 to 1.79055, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 478ms/step - accuracy: 0.2639 - loss: 1.8165 - val_accuracy: 0.2444 - val_loss: 1.7905
# Epoch 9/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step - accuracy: 0.2749 - loss: 1.7338
# Epoch 9: val_loss did not improve from 1.79055
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 483ms/step - accuracy: 0.2764 - loss: 1.7334 - val_accuracy: 0.2622 - val_loss: 1.7909
# Epoch 10/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step - accuracy: 0.3114 - loss: 1.7256
# Epoch 10: val_loss did not improve from 1.79055
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 481ms/step - accuracy: 0.3117 - loss: 1.7249 - val_accuracy: 0.2222 - val_loss: 1.8616
# Epoch 11/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step - accuracy: 0.2926 - loss: 1.7349
# Epoch 11: val_loss improved from 1.79055 to 1.79043, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 492ms/step - accuracy: 0.2944 - loss: 1.7330 - val_accuracy: 0.2889 - val_loss: 1.7904
# Epoch 12/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step - accuracy: 0.3664 - loss: 1.6590
# Epoch 12: val_loss improved from 1.79043 to 1.78589, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 496ms/step - accuracy: 0.3658 - loss: 1.6591 - val_accuracy: 0.2356 - val_loss: 1.7859
# Epoch 13/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step - accuracy: 0.3099 - loss: 1.6818
# Epoch 13: val_loss improved from 1.78589 to 1.74376, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 494ms/step - accuracy: 0.3106 - loss: 1.6819 - val_accuracy: 0.3200 - val_loss: 1.7438
# Epoch 14/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step - accuracy: 0.3030 - loss: 1.7027
# Epoch 14: val_loss improved from 1.74376 to 1.73210, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 495ms/step - accuracy: 0.3047 - loss: 1.6998 - val_accuracy: 0.3111 - val_loss: 1.7321
# Epoch 15/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step - accuracy: 0.3556 - loss: 1.6305
# Epoch 15: val_loss did not improve from 1.73210
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 502ms/step - accuracy: 0.3548 - loss: 1.6321 - val_accuracy: 0.3067 - val_loss: 1.7337
# Epoch 16/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step - accuracy: 0.3455 - loss: 1.6363
# Epoch 16: val_loss did not improve from 1.73210
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 14s 497ms/step - accuracy: 0.3460 - loss: 1.6354 - val_accuracy: 0.2667 - val_loss: 1.8388
# Epoch 17/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step - accuracy: 0.3551 - loss: 1.5930
# Epoch 17: val_loss did not improve from 1.73210
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 502ms/step - accuracy: 0.3536 - loss: 1.5941 - val_accuracy: 0.2578 - val_loss: 1.7549
# Epoch 18/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - accuracy: 0.3700 - loss: 1.5606
# Epoch 18: val_loss did not improve from 1.73210
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 508ms/step - accuracy: 0.3693 - loss: 1.5600 - val_accuracy: 0.2978 - val_loss: 1.7861
# Epoch 19/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step - accuracy: 0.3265 - loss: 1.6634
# Epoch 19: val_loss did not improve from 1.73210
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 510ms/step - accuracy: 0.3276 - loss: 1.6621 - val_accuracy: 0.2711 - val_loss: 1.8772
# Epoch 20/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - accuracy: 0.3475 - loss: 1.5941
# Epoch 20: val_loss did not improve from 1.73210
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 514ms/step - accuracy: 0.3495 - loss: 1.5918 - val_accuracy: 0.2578 - val_loss: 2.0391
# Epoch 21/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.3305 - loss: 1.6855
# Epoch 21: val_loss did not improve from 1.73210
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 521ms/step - accuracy: 0.3322 - loss: 1.6789 - val_accuracy: 0.3111 - val_loss: 1.7793
# Epoch 22/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.3570 - loss: 1.5723
# Epoch 22: val_loss improved from 1.73210 to 1.66940, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 15s 528ms/step - accuracy: 0.3572 - loss: 1.5707 - val_accuracy: 0.3644 - val_loss: 1.6694
# Epoch 23/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 551ms/step - accuracy: 0.3511 - loss: 1.4987
# Epoch 23: val_loss did not improve from 1.66940
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 590ms/step - accuracy: 0.3519 - loss: 1.4983 - val_accuracy: 0.3600 - val_loss: 1.6793
# Epoch 24/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.4032 - loss: 1.4277
# Epoch 24: val_loss improved from 1.66940 to 1.64893, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 537ms/step - accuracy: 0.4038 - loss: 1.4288 - val_accuracy: 0.3689 - val_loss: 1.6489
# Epoch 25/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.4060 - loss: 1.4700
# Epoch 25: val_loss improved from 1.64893 to 1.59791, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 546ms/step - accuracy: 0.4080 - loss: 1.4671 - val_accuracy: 0.3689 - val_loss: 1.5979
# Epoch 26/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - accuracy: 0.3649 - loss: 1.5360
# Epoch 26: val_loss did not improve from 1.59791
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 605ms/step - accuracy: 0.3669 - loss: 1.5319 - val_accuracy: 0.2711 - val_loss: 1.9199
# Epoch 27/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 566ms/step - accuracy: 0.3983 - loss: 1.5189
# Epoch 27: val_loss improved from 1.59791 to 1.58429, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 592ms/step - accuracy: 0.4003 - loss: 1.5151 - val_accuracy: 0.4000 - val_loss: 1.5843
# Epoch 28/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 552ms/step - accuracy: 0.4363 - loss: 1.4739
# Epoch 28: val_loss did not improve from 1.58429
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 598ms/step - accuracy: 0.4360 - loss: 1.4723 - val_accuracy: 0.3467 - val_loss: 1.6440
# Epoch 29/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 554ms/step - accuracy: 0.4631 - loss: 1.3811
# Epoch 29: val_loss did not improve from 1.58429
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 570ms/step - accuracy: 0.4628 - loss: 1.3805 - val_accuracy: 0.3689 - val_loss: 1.5937
# Epoch 30/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 0.4298 - loss: 1.4202
# Epoch 30: val_loss did not improve from 1.58429
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 605ms/step - accuracy: 0.4317 - loss: 1.4174 - val_accuracy: 0.3333 - val_loss: 1.6246
# Epoch 31/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - accuracy: 0.4551 - loss: 1.3416
# Epoch 31: val_loss improved from 1.58429 to 1.57443, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 565ms/step - accuracy: 0.4554 - loss: 1.3416 - val_accuracy: 0.3733 - val_loss: 1.5744
# Epoch 32/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 575ms/step - accuracy: 0.5060 - loss: 1.3144
# Epoch 32: val_loss did not improve from 1.57443
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 598ms/step - accuracy: 0.5039 - loss: 1.3160 - val_accuracy: 0.4178 - val_loss: 1.6151
# Epoch 33/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - accuracy: 0.4627 - loss: 1.4113
# Epoch 33: val_loss improved from 1.57443 to 1.53042, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 611ms/step - accuracy: 0.4628 - loss: 1.4102 - val_accuracy: 0.4000 - val_loss: 1.5304
# Epoch 34/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 571ms/step - accuracy: 0.4932 - loss: 1.3189
# Epoch 34: val_loss improved from 1.53042 to 1.51930, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 17s 601ms/step - accuracy: 0.4935 - loss: 1.3171 - val_accuracy: 0.4267 - val_loss: 1.5193
# Epoch 35/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 588ms/step - accuracy: 0.5066 - loss: 1.2149
# Epoch 35: val_loss did not improve from 1.51930
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 613ms/step - accuracy: 0.5052 - loss: 1.2184 - val_accuracy: 0.4044 - val_loss: 1.5763
# Epoch 36/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 584ms/step - accuracy: 0.5005 - loss: 1.2263
# Epoch 36: val_loss improved from 1.51930 to 1.47222, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 605ms/step - accuracy: 0.5015 - loss: 1.2263 - val_accuracy: 0.4178 - val_loss: 1.4722
# Epoch 37/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 525ms/step - accuracy: 0.5051 - loss: 1.3136
# Epoch 37: val_loss did not improve from 1.47222
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 545ms/step - accuracy: 0.5051 - loss: 1.3116 - val_accuracy: 0.4222 - val_loss: 1.4990
# Epoch 38/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.5233 - loss: 1.2250
# Epoch 38: val_loss did not improve from 1.47222
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 551ms/step - accuracy: 0.5221 - loss: 1.2262 - val_accuracy: 0.4044 - val_loss: 1.5475
# Epoch 39/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.5471 - loss: 1.1124
# Epoch 39: val_loss improved from 1.47222 to 1.42300, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 558ms/step - accuracy: 0.5463 - loss: 1.1156 - val_accuracy: 0.4667 - val_loss: 1.4230
# Epoch 40/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 536ms/step - accuracy: 0.4876 - loss: 1.3525
# Epoch 40: val_loss did not improve from 1.42300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 556ms/step - accuracy: 0.4900 - loss: 1.3463 - val_accuracy: 0.4089 - val_loss: 1.4432
# Epoch 41/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.5404 - loss: 1.1065
# Epoch 41: val_loss did not improve from 1.42300
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 553ms/step - accuracy: 0.5412 - loss: 1.1071 - val_accuracy: 0.4356 - val_loss: 1.4838
# Epoch 42/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.5469 - loss: 1.1848
# Epoch 42: val_loss improved from 1.42300 to 1.36235, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 556ms/step - accuracy: 0.5482 - loss: 1.1821 - val_accuracy: 0.4844 - val_loss: 1.3624
# Epoch 43/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.5866 - loss: 1.0505
# Epoch 43: val_loss did not improve from 1.36235
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 557ms/step - accuracy: 0.5865 - loss: 1.0517 - val_accuracy: 0.4578 - val_loss: 1.4824
# Epoch 44/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 0.5969 - loss: 0.9989
# Epoch 44: val_loss did not improve from 1.36235
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 559ms/step - accuracy: 0.5965 - loss: 1.0026 - val_accuracy: 0.4222 - val_loss: 1.5917
# Epoch 45/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.4966 - loss: 1.2344
# Epoch 45: val_loss did not improve from 1.36235
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 551ms/step - accuracy: 0.4981 - loss: 1.2317 - val_accuracy: 0.3600 - val_loss: 1.7989
# Epoch 46/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.5403 - loss: 1.0931
# Epoch 46: val_loss improved from 1.36235 to 1.35171, saving model to model/emobase_feat/SER_RAVDESS_Clean05_10_2024_12_41_13.keras
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 553ms/step - accuracy: 0.5434 - loss: 1.0892 - val_accuracy: 0.5111 - val_loss: 1.3517
# Epoch 47/1000
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.5485 - loss: 1.1776
# Epoch 47: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 559ms/step - accuracy: 0.5483 - loss: 1.1783 - val_accuracy: 0.4311 - val_loss: 1.4168
# Epoch 48/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 535ms/step - accuracy: 0.5659 - loss: 1.0989
# Epoch 48: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 555ms/step - accuracy: 0.5667 - loss: 1.0969 - val_accuracy: 0.4711 - val_loss: 1.4725
# Epoch 49/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.6232 - loss: 0.9811
# Epoch 49: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 549ms/step - accuracy: 0.6222 - loss: 0.9827 - val_accuracy: 0.4622 - val_loss: 1.4367
# Epoch 50/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.5640 - loss: 1.1399
# Epoch 50: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 554ms/step - accuracy: 0.5657 - loss: 1.1360 - val_accuracy: 0.4800 - val_loss: 1.5496
# Epoch 51/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.6481 - loss: 0.9505
# Epoch 51: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 551ms/step - accuracy: 0.6476 - loss: 0.9503 - val_accuracy: 0.4978 - val_loss: 1.4475
# Epoch 52/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 532ms/step - accuracy: 0.6584 - loss: 0.9139
# Epoch 52: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 552ms/step - accuracy: 0.6576 - loss: 0.9155 - val_accuracy: 0.4667 - val_loss: 1.3875
# Epoch 53/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.5931 - loss: 0.9694
# Epoch 53: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 553ms/step - accuracy: 0.5946 - loss: 0.9690 - val_accuracy: 0.4889 - val_loss: 1.4983
# Epoch 54/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 537ms/step - accuracy: 0.6674 - loss: 0.8309
# Epoch 54: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 556ms/step - accuracy: 0.6656 - loss: 0.8338 - val_accuracy: 0.4400 - val_loss: 1.4162
# Epoch 55/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 538ms/step - accuracy: 0.5647 - loss: 1.1063
# Epoch 55: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 558ms/step - accuracy: 0.5657 - loss: 1.1042 - val_accuracy: 0.4267 - val_loss: 1.5929
# Epoch 56/1000
# 28/29 ━━━━━━━━━━━━━━━━━━━━ 0s 531ms/step - accuracy: 0.5356 - loss: 1.1667
# Epoch 56: val_loss did not improve from 1.35171
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 16s 555ms/step - accuracy: 0.5360 - loss: 1.1641 - val_accuracy: 0.4711 - val_loss: 1.3861
# Epoch 56: early stopping
# Restoring model weights from the end of the best epoch: 46.
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.5677 - loss: 1.2449
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - accuracy: 0.5677 - loss: 1.2449
# Loss : 1.2817312479019165, Accuracy : 0.5519999861717224

# %%
model.evaluate(X,Y)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 5s 252ms/step - accuracy: 0.1483 - loss: 1.9782
# [1.9752070903778076, 0.1428571492433548]
